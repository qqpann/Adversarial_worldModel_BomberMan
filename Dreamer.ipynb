# %% [markdown]
# # 2022年 世界モデル第5回演習
#
# 本演習では, いわゆる世界モデルを用いた強化学習アルゴリズムである **RSSM (Recurrent State Space Model)**[[1]](#scrollTo=J_PCEOJ69prx) と**Dreamer**[[2]](#scrollTo=J_PCEOJ69prx)を実装します.
#
# 1. [準備](#scrollTo=yDN8Ohc0Mh8C)
# 2. [環境の設定](#scrollTo=_eayBK1HPV5H)
# 3. [RSSM](#scrollTo=B3rWEGtkA3e_&line=1&uniqifier=1)
# 4. [RSSMの実装](#scrollTo=xJfU7ygCMeJn)
# 5. [補助機能の実装](#scrollTo=WhlVvU3aZ5FC)
# 6. [Dreamerの実装](#scrollTo=keAW0J-qS24Q)
# 7. [エージェントの実装](#scrollTo=GdKZ1S2_boOd)
# 8. [ハイパーパラメータの設定と学習の準備](#scrollTo=QUPWAkpyc9Z-)
# 9. [学習](#scrollTo=yUoI0l9Ee0Tp)
# 10. [結果の確認](#scrollTo=E3F2tAU0kepm)
# 11. [参考文献](##scrollTo=J_PCEOJ69prx&line=4&uniqifier=1)

# %% [markdown]
# ##1.準備
# まず, 演習を行うために必要な準備を行います.

# %% [markdown]
# この演習では, 環境として[PyBullet](https://github.com/bulletphysics/bullet3)を用います. PyBulletは`pip`を用いてインストールします.

# %%
# !pip install pybullet
# Out:
# Requirement already satisfied: pybullet in /usr/local/lib/python3.7/dist-packages (3.2.2)

# %% [markdown]
# 必要なライブラリをインポートします. 今回使うライブラリは, PyBullet以外はColabでは最初から入っていますが, 手元の環境で行う場合はこれらのライブラリも`pip`等で事前にインストールする必要があります.

# %%
import time
import os

import gym
import pybullet_envs  # PyBulletの環境をgymに登録する

import numpy as np
import matplotlib.pyplot as plt

import torch
from torch.distributions import Normal
from torch.distributions.kl import kl_divergence
from torch import nn
from torch.nn import functional as F
from torch.nn.utils import clip_grad_norm_
from torch.utils.tensorboard import SummaryWriter

# 可視化のためにTensorBoardを用いるので, Colab上でTensorBoardを表示するための宣言を行う
# %load_ext tensorboard
torch.set_default_tensor_type('torch.cuda.FloatTensor')
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# 今回の学習にはGPUが必要です．
#
# 以下のコードを実行して， 結果が'cuda'でなければ「ランタイム」 →　 「ランタイムのタイプを変更」でGPUモードに変更しましょう．

# %%
# torch.deviceを定義. この変数は後々モデルやデータをGPUに転送する時にも使います
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# きちんとGPUが使える状態になっているかチェックしておきます． ColabのGPU割り当てにはランダム性があるので人によって結果が違う場合がありますが， どれでも実行には問題ありません（学習にかかる時間に幾らかの差は出ます）.

# %%
# !nvidia-smi
# Out:
# Sun Apr  3 09:40:37 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    11W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 2.環境の設定

# %% [markdown]
# ###1.ゲーム基幹部分

# %% [markdown]
# #### import

# %%
import cv2
import copy
from google.colab.patches import cv2_imshow
from PIL import Image
from gym.spaces import *
import random

# %%
# ToDO:rootフォルダを確認
path = "/content/drive/MyDrive/Colab Notebooks/Adversarial_worldModel_BomberMan"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### ゲームルール

# %% [markdown]
# 各マスのid割り当てとその意味
#
# | id |意味|
# |:---|:---|
# |0|空白|
# |1|破壊不可オブジェクト|
# |2|破壊可能オブジェクト(レンガ)|
# |1X|キャラ(X = id)|
# |10X|爆弾(X = 置いた人のプレイヤーid)|
#
# アクション
#
# | id |意味|
# |:---|:---|
# |0|何もしない|
# |1|上に移動|
# |2|下に移動|
# |3|右に移動|
# |4|左に移動|
# |5|爆弾を設置|
#
# x軸が縦、y軸が横
#
# 学習時renderには連番で投げる

# %% [markdown]
# #### ゲーム情報定義

# %%
# フィールドのサイズ定義　両方奇数である前提で行っている
boardXsize = 13
boardYsize = 11
# フィールドにおける爆弾の合計の上限数
MAXBOMBS = 20
ITEMS = 3
# プレイヤー人数　現状2である前提
player_count = 2
# 行動可能なアクションの数
n_actions = 6
# 最初においてあるレンガの数
brickCount = 40# boardXsize * boardYsize - 58
# ゲームクラスのデバッグ用
logDisp = False
# 各modelの可視化用
dummyCheck = True

# %%
assert boardXsize % 2 == 1 and boardYsize % 2 == 1
assert player_count == 2

# %% [markdown]
# ##### 報酬設定(ゲーム内で表示されるスコアの定義)

# %%
# 爆弾が相手に当たったときの報酬
ONBOMHIT = 1
# 相手からの爆弾が当たったときの報酬
ONBOMHITTED = -0.1
# 自分の爆弾が当たったときの報酬
ONBOMSELF = -1
# レンガを壊した時に得られる報酬
ONBREAKBRICK = 0
# 接近ボーナス
CLOSEBONUS = 0.2
# 勝利ボーナス
WIN = 0.1
# 敗北ボーナス
LOSE = -0.1
# 壁にぶつかる、爆弾の設置数が上限に達している行動をしたときのペナルティー
INVALID_ACTION_PENALTY = -0.008
# 生存ごとに毎step得る報酬
ALLIVE = 0
# ステップ上限に達したときのペナルティー
OVERTIME_PENALTY = -10

# %% [markdown]
# #####パラメータ、便利関数

# %%
def pos2v(val):
    return val[0], val[1]

def nearInt(val):
    return int(val + 0.5)

def isInBoard(p):
    if 0 <= p[0] and p[0] < boardXsize and 0 <= p[1] and p[1] < boardYsize:
        return True
    else:
        return False

def rand_ints_nodup(a, b, k):
    ns = []
    if k > b : k = b
    while len(ns) < k:
        n = np.random.randint(a, b)
        if not n in ns:
            ns.append(n)
    return ns

V = np.array([[0, -1], [0, 1], [1, 0], [-1, 0]])

# %% [markdown]
# ##### マップ用画像読み込み

# %%
pix_size = 1
windowXsize = boardXsize * pix_size
windowYsize = boardYsize * pix_size
# 人間の目に優しいように
chip_none = cv2.imread(path + "/BomberMan/chips/none.jpg")
chip_block = cv2.imread(path + "/BomberMan/chips/block.jpg")
chip_bomb = cv2.imread(path + "/BomberMan/chips/bom.jpg")
chip_brick = cv2.imread(path + "/BomberMan/chips/brick.jpg")
chip_enemy = cv2.imread(path + "/BomberMan/chips/enemy.jpg")
chip_player = cv2.imread(path + "/BomberMan/chips/player.jpg")
chip_bomb_on_me = cv2.imread(path + "/BomberMan/chips/bomonme.jpg")
chip_bomb_on_enemy = cv2.imread(path + "/BomberMan/chips/bomonenemy.jpg")

# %% [markdown]
# ### ゲームクラス

# %% [markdown]
# 基本の流れ
# 対戦型のため普通のgymのように使えないため ToDO:Read it
# addActionで各プレイヤーの行動を設定、stepで行動を実行
# また報酬なども配列で返す

# %% [markdown]
# Player
#
# |クラス内変数|説明|
# |:---|:---|
# |id|プレイヤーid(0～)|
# |life|残機|
# |pos|位置|
# |bombMax|プレイヤーが置ける上限爆弾数|
# |setBomb|プレイヤーが置いた爆弾数|
# |bombLen|このプレイヤーの置いた爆弾が燃え広がる長さ|
# |score|得点|
#
# Bomb
#
# |クラス内変数|説明|
# |:---|:---|
# |isActive|この爆弾idが今使われているか|
# |timer|起爆するまでのtick|
# |who|爆弾を置いたひとのid|
# |len|この爆弾の燃え広がる長さ|
# |pos|爆弾の位置|
#
# Env
#
# |クラス内変数|説明|
# |:---|:---|
# |actions|各プレイヤーがそのtickにとった行動|
# |playableId|playableId[pid]が1のときpidが生存していることを示す|
# |players|Player()のインスタンス配列|
# |bombs|Bomb()のインスタンス配列|
# |boardHistory|ゲーム内用の盤面の履歴|
# |isFin|doneと同義|
#
#
# |関数|説明|返り値|
# |:---|:---|:---|
# |addAction(pid, action)|pidがactionを行う予定を追加||
# |resetBoard()|Boardの初期化||
# |setBrick(cnt)|cntの数だけおける場所にレンガを置く||
# |render(pid)|pidから見た学習用の盤面を返す|np.array([boardXsize, boardYsize])|
# |renderForHuman(self, pid, board = None)|pidから見た人間用の盤面を返す|cv2|
# |renderToGif(pid, path)|"root+path.gif"に今の環境のプレイ履歴をgifで保存する||
# |rewards()|報酬の配列を獲得する|[pid, value]|
# |observations()|各プレイヤーからみたboardを返す|[pid, np.array([1, boardXsize, boardYsize])]|
#
# render(pid)は各値が[0, ITEMS+4]の範囲にあるので必要に応じてクリッピングしている
# 本来は画像でやりとりするため現状のrender(pid)は必要ない関数ではある...(renderForHumanでやるべき)
# renderForHuman()のboardにNoneをいれると現在の盤面を返し、任意のゲーム内用配列を入れるとそれを出力する

# %% [markdown]
# ##### class

# %%
class Player:
    def __init__(self, id = 0):
        self.id = id
        self.life = 10
        self.pos = np.array([0, 0])
        self.bombMax = 2
        self.setBomb = 0
        self.bombLen = 15
        self.score = 0.0
    
    def _changePos(self, pos):
        self.pos = pos
    
    def scoring(self, score):
        self.score += score

    def dmg(self):
        self.life -= 1
        if logDisp : print(f"{self.id}の残機減少：残り{self.life}")
    
    def isSurvive(self):
        if self.life > 0 : return True
        else : return False 

class Bomb:
    def __init__(self):
        self.isActive = False
        self.timer = 8
        self.who = -1
        self.len = -1
        self.pos = [-1,-1]
    
    def activate(self, pos, id, len):
        self.pos = pos
        self.who = id
        self.len = len
        self.isActive = True

class Env(gym.Env):
    def __init__(self, isRenderImg = False, isOutdataSingle = False):
        self.isRenderImg = isRenderImg
        self.isOutdataSingle = isOutdataSingle
        self.reset()
        # 以下gym用
        self.action_space = gym.spaces.Discrete(6)
        if isRenderImg:
            LOW = np.array([0 for i in range(3 * 64 * 64)]).reshape(64, 64, 3)
            HIGH = np.array([1 for i in range(3 * 64 * 64)]).reshape(64, 64, 3)
        else:
            LOW = np.array([0 for i in range(boardXsize * boardYsize)]).reshape(1, boardXsize, boardYsize)
            HIGH = np.array([1 for i in range(boardXsize * boardYsize)]).reshape(1, boardXsize, boardYsize)
        self.observation_space = gym.spaces.Box(low=LOW, high=HIGH)

    def reset(self):
        self.isFin = False
        self.actions = [-1 for i in range(player_count)]
        self.playableId = [1 for i in range(player_count)]
        self.players = [Player(i) for i in range(player_count)]
        self.bombs = [Bomb() for i in range(MAXBOMBS)]
        self.distance_t0 = 999.0
        self.boardHistory = []
        self.scoreHistory = []
        self.actionHistory = []
        self.posHistory = []
        self.resetBoard()
        self.addHistory()
        return self.observations()

    # 盤面リセット
    def resetBoard(self):
        # 盤面初期化
        self.board = np.zeros([boardXsize, boardYsize])

        # 破壊不可オブジェクト配置
        for x in range(1, boardXsize, 2):
            for y in range(1, boardYsize, 2):
                self.board[x, y] = 1
        
        # プレイヤー初期位置定義
        init_pos = np.array([[0, 0], [boardXsize - 1, boardYsize - 1], [0, boardYsize - 1], [boardXsize - 1, 0]])
        for i in range(player_count):
            self.board[pos2v(init_pos[i])] = 10 + i
            self.players[i]._changePos(pos = init_pos[i])
        
        self.setBrick(brickCount)

    # レンガ配置
    # プレイヤーの上下左右1マスは設置不可
    def setBrick(self, cnt):
        unsettable = []
        for player in self.players:
            for v in V:
                p = np.add(player.pos, v)
                if isInBoard(p) and self.board[pos2v(p)] == 0:
                    unsettable.append(p)
        
        settable = []
        for x, board_x in enumerate(self.board):
            for y, board_elm in enumerate(board_x):
                if board_elm == 0 and not any([np.allclose(p, [x, y]) for p in unsettable]):
                    settable.append([x, y])
        
        bricks_pos = rand_ints_nodup(0, len(settable), cnt)
        for b in bricks_pos:
            self.board[pos2v(settable[b])] = 2

    def addHistory(self):
        self.boardHistory.append(copy.deepcopy(self.board))
        self.scoreHistory.append([self.players[i].score for i in range(player_count)])
        self.actionHistory.append(copy.deepcopy(self.actions))
        self.posHistory.append([self.players[i].pos for i in range(player_count)])

    # キャラの移動処理
    def move(self, pid, direction):
        p = np.add(self.players[pid].pos, V[direction])
        if logDisp : print(f"{pid}は{p}に移動")
        if isInBoard(p):
            # 空白の時のみ移動可能
            if self.board[pos2v(p)] == 0:
                self.board[pos2v(self.players[pid].pos)] -= pid + 10
                self.board[pos2v(p)] += pid + 10
                self.players[pid]._changePos(p)
            else:
                self.onCollision(pid)
        else:
            self.onCollision(pid)

    # 壁など衝突 ToDo:減点処理...?
    def onCollision(self, pid):
        self.players[pid].scoring(INVALID_ACTION_PENALTY)

    # 爆弾セット
    def bombSet(self, pid, pos):
        # 爆弾がすでにあるかおける上限を超えたとき処理をスキップ
        if self.board[pos2v(pos)] >= 100 or self.players[pid].setBomb >= self.players[pid].bombMax:
            if logDisp : print(f"pid:{pid}は爆弾が置けない")
            self.players[pid].scoring(INVALID_ACTION_PENALTY)
            return
        for i in range(MAXBOMBS):
            if not self.bombs[i].isActive:
                self.bombs[i].activate(pos, pid, self.players[pid].bombLen)
                self.board[pos2v(pos)] += 100
                self.players[pid].setBomb += 1
                break

    # 爆弾tick
    def bombTick(self):
        for i in range(MAXBOMBS):
            if self.bombs[i].isActive:
                  self.bombs[i].timer -= 1
                  if self.bombs[i].timer <= 0:
                      self.bombDmg(i)
                      self.bombs[i].__init__()    

    # 爆弾爆発処理
    def bombDmg(self, bomId):
        pos = self.bombs[bomId].pos
        if logDisp : print(f"{pos}で{self.bombs[bomId].who}の爆弾が長さ{self.bombs[bomId].len}で爆発")
        # 爆弾を置いた人が置けるようにする
        self.players[self.bombs[bomId].who].setBomb -= 1
        # 爆発跡地
        self.board[pos2v(pos)] -= 100
        self.exploseCheck(pos, bomId)
        for v in V:
            for i in range(1, self.bombs[bomId].len):
                p = np.add(pos, v * i)
                if isInBoard(p):
                    if self.exploseCheck(p, bomId) == 1:
                        break
                else:
                    break      

    # 爆発後の地形変化 1を返すとき爆発がそこで止まることを示している
    def exploseCheck(self, p, bomId):
        whosBom = self.bombs[bomId].who
        if logDisp : print(f"{p}は{self.board[pos2v(p)]}")
        # 破壊不能の場合終了
        if int(self.board[pos2v(p)]) == 1:
            return 1
        # レンガの場合レンガを破壊して終了
        elif int(self.board[pos2v(p)]) == 2:
            self.board[pos2v(p)] = 0
            self.players[whosBom].scoring(ONBREAKBRICK)
            return 1
        # 爆弾の場合次のtickに連鎖爆発
        elif int(self.board[pos2v(p)]) >= 100:
            for i in range(MAXBOMBS):
              if np.allclose(self.bombs[i].pos, p):
                  if self.bombs[i].timer >= 2:
                      self.bombs[i].timer = 1
                  return 0
        # プレイヤーの場合ダメージ処理
        elif int(self.board[pos2v(p)]) >= 10:
            damagedPid = int(self.board[pos2v(p)]) % 10
            self.players[damagedPid].dmg()
            if logDisp : print(f"{damagedPid}が被弾")

            # 爆弾を当てたrewardと被弾reward
            if whosBom != damagedPid:
                self.players[whosBom].scoring(ONBOMHIT)
                self.players[damagedPid].scoring(ONBOMHITTED)
            else:
                self.players[damagedPid].scoring(ONBOMSELF)
            
            if not self.players[damagedPid].isSurvive():
                self.playableId[damagedPid] = 0
                self.players[damagedPid].scoring(LOSE)
                if whosBom != damagedPid:
                    self.players[whosBom].scoring(WIN)
            
            return 0

    # 相手に向かっているときボーナス
    def closeBonus(self):
        distance_t1 = np.linalg.norm(self.players[0].pos - self.players[1].pos)
        if self.distance_t0 > distance_t1:
            for pid in range(player_count):
                # 待機じゃなければ/今は待機でもスコアリングできるようにしてある
                #if 1 <= self.actions[pid] and self.actions[pid] <= 4:
                    self.players[pid].scoring(CLOSEBONUS)
            self.distance_t0 = distance_t1
    
    # 出力
    def render(self, pid):
        if self.isRenderImg:
            return self._renderToImg(pid)
        else:
            board = copy.deepcopy(self.board)
            for x in range(boardXsize):
                for y in range(boardYsize):
                    chip = int(board[x, y])
                    if 10 <= chip and chip < 100:
                        if chip == pid + 10:
                            board[x, y] = ITEMS
                        # 敵性プレイヤー
                        else:
                            board[x, y] = ITEMS + 1
                    # 爆弾
                    elif chip== 100:
                        board[x, y] = ITEMS + 2
                    # 爆弾onMe
                    elif chip == 110 + pid:
                        board[x, y] = ITEMS + 3
                    # 爆弾onEnemy
                    elif not chip < ITEMS:
                        board[x, y] = ITEMS + 4
                        
            return board

    def renderForHuman(self, pid, board = None):
        b = self.board
        if type(board) != type(None):
            b = board
        img = []
        for x in range(boardXsize):
            img_x = []
            for y in range(boardYsize):
                if b[x, y] == 0:
                    img_x.append(chip_none)
                elif b[x, y] == 1:
                    img_x.append(chip_block)
                elif b[x, y] == 2:
                    img_x.append(chip_brick)
                elif b[x, y] == 10 + pid:
                    img_x.append(chip_player)
                elif 10 <= b[x, y] and b[x, y] < 100:
                    img_x.append(chip_enemy)
                elif b[x, y] == 100:
                    img_x.append(chip_bomb)
                elif b[x, y] == 110 + pid:
                    img_x.append(chip_bomb_on_me)
                else:
                    img_x.append(chip_bomb_on_enemy)
            img_x = cv2.vconcat(img_x)
            img.append(img_x)
        img = cv2.hconcat(img)
        return img

    def _renderToImg(self, pid = 0, pixSize = [64, 64]):
        img = self.renderForHuman(pid)
        img = cv2.pyrUp(img)
        img = cv2.resize(img, dsize = (64, 64))
        return img

    def renderToGif(self, pid = 0, path = "play"):
        images = []
        for i, board in enumerate(self.boardHistory):
            img = cv2.pyrUp(self.renderForHuman(pid = pid, board = board))

            # スコア表示
            score = np.zeros((8 * 2, windowXsize * 8 * 2, 3), np.uint8)
            score = cv2.putText(score,
                text = "step:" + str('{:03}'.format(i)) + " | " +\
                   str('{:.5f}'.format(self.scoreHistory[i][0])) + " | " + str('{:.5f}'.format(self.scoreHistory[i][1])),
                org=(0, 10),
                fontFace=cv2.FONT_HERSHEY_SIMPLEX,
                fontScale=0.2,
                color=(255, 255, 255),
                thickness=1,
                lineType=cv2.LINE_4)

            # 行動表示
            for j in range(player_count):
                if 1 <= self.actionHistory[i][j]:
                    text = ["^", "v", ">", "<", "b"][self.actionHistory[i][j] - 1]
                    img = cv2.putText(img, text, (self.posHistory[i][j][0] * 16 + 8, self.posHistory[i][j][1] * 16 + 8), cv2.FONT_HERSHEY_SIMPLEX , 0.2, (255, 255, 255), 1)

            img = cv2.vconcat([img, score])
            images.append(Image.fromarray(img))

        images[0].save(path + ".gif", save_all = True, append_images = images[1:], duration=300, loop=0)

    # 以下gym用の関数

    # リワード設定
    def rewards(self):
        if self.isOutdataSingle:
            return self.players[0].score
        else:
            return [self.players[i].score for i in range(player_count)]
    
    # 観測
    def observations(self):
        if self.isOutdataSingle:
            if self.isRenderImg:
                return self.render(pid = 0)
            else:
                return torch.Tensor(self.render(pid = 0).reshape(1, windowXsize, windowYsize))
        else:
            rets = []
            for pid in range(player_count):
                if self.isRenderImg:
                    rets.append(self.render(pid = pid))
                else:
                    rets.append(torch.Tensor(self.render(pid = pid).reshape(1, windowXsize, windowYsize)))
            return rets

    # アクション登録
    def addAction(self, pid, action):
        if isinstance(action, np.ndarray):
            action = np.argmax(action)
        
        if pid < player_count and action <= n_actions:
                self.actions[pid] = action

    
    # 時間経過
    def step(self):
        for pid in range(player_count):
            action = self.actions[pid]
            if 1 <= action and action <= 4:
                self.move(pid, action - 1)
            elif action == 5:
                self.bombSet(pid, self.players[pid].pos)

        if len(self.boardHistory) >= 800:
            self.isFin = True
            for pid in range(player_count):
                self.players[pid].scoring(OVERTIME_PENALTY)

        if not self.isFin:
            self.bombTick()
            self.closeBonus()

            if sum(self.playableId) <= 1:
                self.isFin = True

        # 生存スコア計算
        for pid in range(player_count):
            if self.actions[pid] != 0:
                self.players[pid].scoring(ALLIVE)
            else:
                self.players[pid].scoring(INVALID_ACTION_PENALTY)
        
        self.addHistory()

        return self.observations(), self.rewards(), self.isFin, {}

# %%
# renderForHumanと同義
def matToImg(mat, fromFloat = False, pid = 0):
    mat = np.array(copy.deepcopy(mat).reshape(windowXsize, windowYsize))
    # 学習用に[0,1]の範囲にされたものをゲーム処理用に直す
    if fromFloat:
        mat *= (ITEMS + 4)
        for x in range(boardXsize):
            for y in range(boardYsize):
                chip = nearInt(mat[x, y])
                if chip == ITEMS:
                    mat[x, y] = 10
                elif chip == ITEMS + 1:
                    mat[x, y] = 11
                elif chip == ITEMS + 2:
                    mat[x, y] = 100
                elif chip == ITEMS + 3:
                    mat[x, y] = 110
                elif not chip < ITEMS:
                    mat[x, y] = 111
                else:
                    mat[x, y] = chip
    img = []
    # ゲーム処理用の配列をEnv()のインスタンスがないためここで人間用の画像に処理
    for x in range(boardXsize):
        img_x = []
        for y in range(boardYsize):
            if mat[x, y] == 0:
                img_x.append(chip_none)
            elif mat[x, y] == 1:
                img_x.append(chip_block)
            elif mat[x, y] == 2:
                img_x.append(chip_brick)
            elif mat[x, y] == 10 + pid:
                img_x.append(chip_player)
            elif 10 <= mat[x, y] and mat[x, y] < 100:
                img_x.append(chip_enemy)
            elif mat[x, y] == 100:
                img_x.append(chip_bomb)
            elif mat[x, y] == 110 + pid:
                img_x.append(chip_bomb_on_me)
            else:
                img_x.append(chip_bomb_on_enemy)
        img_x = cv2.vconcat(img_x)
        img.append(img_x)
    img = cv2.hconcat(img)
    return img

# %% [markdown]
# ### 環境テスト

# %%
def make_env():
    env = Env(isRenderImg = True, isOutdataSingle = True)
    return env

# %%
env = make_env()
pid = 0
img = env._renderToImg(pid = pid)
for i in range(10):
    env.addAction(0, random.randint(0, 5))
    env.addAction(1, random.randint(0, 5))
    observations, rewards, isFin, _ = env.step()
env.renderToGif(pid = 0, path = path + "/result/test")
print(env.rewards())
# Out:
# -0.64
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
def print_spaces(space, label = " "):
   # 空間の出力
   print(label, space)

   # Box/Discreteの場合は最大値と最小値も表示
   if isinstance(space, Box):
       print('    最小値: ', space.low)
       print('    最大値: ', space.high)
   if isinstance(space, Discrete):
       print('    最小値: ', 0)
       print('    最大値: ', space.n-1)

# %%
print_spaces(env.action_space)
env.action_space.shape
# Out:
#   Discrete(6)
#     最小値:  0
#     最大値:  5
# ()

# %% [markdown]
# ## 3.RSSM
# RSSMは以下のパーツに分けることができます.
#
# **Deterministic state model:**
# > $h_{t}=f(h_{t-1}, s_{t-1}, a_{t-1})$
#
# **Stochastic state model:**
# > $s_{t}$ ~ $p(s_{t} | h_{t})$
#
# **Observation model:**
# > $o_{t}$ ~ $p(o_{t} | h_{t}, s_{t})$
#
# **Reward model:**
# > $r_{t}$~ $p(r_{t} | h_{t}, s_{t})$
#
# [以下の画像](https://towardsai.net/p/machine-learning/dreamer-8b5a42acebbf)は1つの時間ステップでのRSSMの挙動を示しています.
#
# ![1stepあたりの模式図](https://cdn-images-1.medium.com/max/1024/1*4b2l7Fr4eavQV5ZMouCT-g.png)
#
#
#
# Deterministic state modelで, RNNは, 前の時間ステップの行動$a_{t-1}$と事後確率状態$s'_{t-1}$, 決定論的状態$h_{t-1}$を入力とし, 決定論的状態$h_t$を出力します.
#
# $h_{t}$は (1)事前状態確率$s_{t}$を計算するために, 1つの隠れ層を持つMLPに供給され (本実装では線形変換）, (2)事後確率状態$s'_{t}$を計算するために, 画像埋め込み$e_t$(本実装では`embedded_obs`と表現される）と連結され, 別の単層MLP(線形変換)に供給されます.
#
# その後, $h_{t}$と$s'_{t}$を連結したものを用いて, 画像や報酬などを再構成します.

# %% [markdown]
# ## 4.RSSMの実装
#
#
# 上記をもとにRSSMの実装を行います. 実装では, 以下の3つのクラスに分けて実装します.
#
# * 状態遷移を担うクラス（TransitionModel）
# * 観測を復元するデコーダクラス（ObservationModel）
# * 報酬を予測するクラス（RewardModel）
#
# ※TransitionModelは上記Deterministic state model, Stochastic state modelを合体させています.

# %% [markdown]
# まず実装するのがTransitionModelです.
#
# 1ステップ先の未来の状態表現を予測する機能を担います.
#
# 学習の方針として, 状態遷移を用いた1ステップ先の未来の状態表現の分布である"prior"と, 1ステップ先の観測の情報を取り込んで計算した状態表現の分布である"posterior"が一致するように学習します.
#
# "posterior"は後に観測の再構成誤差と報酬の予測誤差によって学習されるので, "posterior"は上記の2つの誤差によって妥当な状態表現になるように学習され, 同時に"prior"をそれに近づけることで, 状態表現の空間で未来の予測が可能になるように学習する, というイメージです. よって, これを踏まえたクラスの実装になっています.
#
# 状態表現として, 決定的な状態である"rnn_hidden"と, 確率的な状態である"state"の両方を持っています.

# %%
class TransitionModel(nn.Module):
    """
    このクラスは複数の要素を含んでいます.
    決定的状態遷移 （RNN) : h_t+1 = f(h_t, s_t, a_t)
    確率的状態遷移による1ステップ予測として定義される "prior" : p(s_t+1 | h_t+1)
    観測の情報を取り込んで定義される "posterior": q(s_t+1 | h_t+1, e_t+1)
    """
    def __init__(self, state_dim, action_dim, rnn_hidden_dim,
                 hidden_dim=200, min_stddev=0.1, act=F.elu):
        super(TransitionModel, self).__init__()
        self.state_dim = state_dim
        self.action_dim = action_dim
        self.rnn_hidden_dim = rnn_hidden_dim
        self.fc_state_action = nn.Linear(state_dim + action_dim, hidden_dim)
        self.fc_rnn_hidden = nn.Linear(rnn_hidden_dim, hidden_dim)
        self.fc_state_mean_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_prior = nn.Linear(hidden_dim, state_dim)
        self.fc_rnn_hidden_embedded_obs = nn.Linear(rnn_hidden_dim + 1024, hidden_dim)
        self.fc_state_mean_posterior = nn.Linear(hidden_dim, state_dim)
        self.fc_state_stddev_posterior = nn.Linear(hidden_dim, state_dim)

        #next hidden stateを計算
        self.rnn = nn.GRUCell(hidden_dim, rnn_hidden_dim)
        self._min_stddev = min_stddev
        self.act = act
  

    def forward(self, state, action, rnn_hidden, embedded_next_obs):
        """
        h_t+1 = f(h_t, s_t, a_t)
        prior p(s_t+1 | h_t+1) と posterior q(s_t+1 | h_t+1, e_t+1) を返す
        この2つが近づくように学習する
        """
        next_state_prior, rnn_hidden = self.prior(self.reccurent(state, action, rnn_hidden))
        next_state_posterior = self.posterior(rnn_hidden, embedded_next_obs)
        return next_state_prior, next_state_posterior, rnn_hidden
      
    def reccurent(self, state, action, rnn_hidden):
        """
        h_t+1 = f(h_t, s_t, a_t)を計算する
        """
        hidden = self.act(self.fc_state_action(torch.cat([state, action], dim=1)))
        #h_t+1を求める
        rnn_hidden = self.rnn(hidden, rnn_hidden)
        return rnn_hidden

    def prior(self, rnn_hidden):
        """
        prior p(s_t+1 | h_t+1) を計算する
        """
        #h_t+1を求める
        hidden = self.act(self.fc_rnn_hidden(rnn_hidden))

        mean = self.fc_state_mean_prior(hidden)
        stddev = F.softplus(self.fc_state_stddev_prior(hidden)) + self._min_stddev
        return Normal(mean, stddev), rnn_hidden

    def posterior(self, rnn_hidden, embedded_obs):
        """
        posterior q(s_t+1 | h_t+1, e_t+1)  を計算する
        """
        # h_t+1, o_t+1を結合し, q(s_t+1 | h_t+1, e_t+1) を計算する
        hidden = self.act(self.fc_rnn_hidden_embedded_obs(
            torch.cat([rnn_hidden, embedded_obs], dim=1)))
        mean = self.fc_state_mean_posterior(hidden)
        stddev = F.softplus(self.fc_state_stddev_posterior(hidden)) + self._min_stddev
        return Normal(mean, stddev)

# %% [markdown]
# 次に, 観測を再構成するデコーダを実装します.

# %%
class ObservationModel(nn.Module):
    """
    p(o_t | s_t, h_t)
    低次元の状態表現から画像を再構成するデコーダ (3, 64, 64)
    """
    def __init__(self, state_dim, rnn_hidden_dim):
        super(ObservationModel, self).__init__()
        self.fc = nn.Linear(state_dim + rnn_hidden_dim, 1024)
        self.dc1 = nn.ConvTranspose2d(1024, 128, kernel_size=5, stride=2)
        self.dc2 = nn.ConvTranspose2d(128, 64, kernel_size=5, stride=2)
        self.dc3 = nn.ConvTranspose2d(64, 32, kernel_size=6, stride=2)
        self.dc4 = nn.ConvTranspose2d(32, 3, kernel_size=6, stride=2)


    def forward(self, state, rnn_hidden):
        hidden = self.fc(torch.cat([state, rnn_hidden], dim=1))
        hidden = hidden.view(hidden.size(0), 1024, 1, 1)
        hidden = F.relu(self.dc1(hidden))
        hidden = F.relu(self.dc2(hidden))
        hidden = F.relu(self.dc3(hidden))
        obs = self.dc4(hidden)
        return obs

# %% [markdown]
# 次に, 報酬を予測するRewardモデルを実装します.

# %%
class RewardModel(nn.Module):
    """
    p(r_t | s_t, h_t)
    低次元の状態表現から報酬を予測する
    """
    def __init__(self, state_dim, rnn_hidden_dim, hidden_dim=400, act=F.elu):
        super(RewardModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act
 

    def forward(self, state, rnn_hidden):
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        reward = self.fc4(hidden)
        return reward

# %% [markdown]
# 最後に, 上記で定義された３つのモデルを`RSSM`クラスとしてまとめます.

# %%
class RSSM:
    def __init__(self, state_dim, action_dim, rnn_hidden_dim, ):
        self.transition = TransitionModel(state_dim, action_dim, rnn_hidden_dim).to(device)
        self.observation = ObservationModel(state_dim, rnn_hidden_dim,).to(device)
        self.reward = RewardModel(state_dim, rnn_hidden_dim,).to(device)

# %% [markdown]
# ## 5.補助機能の実装
#
# モデルの実装の前に, いくつか学習上必要になる補助機能を実装しておきましょう. 具体的にはリプレイバッファ, 観測の前処理を行う関数, λ-returnを計算する関数 の3つです.

# %% [markdown]
# まずはリプレイバッファを実装します. ただし, RNNを使う関係上一連の系列として経験をサンプルしてくる必要があるため, DQNの時よりは少し実装に工夫が必要です.

# %%
# こちらはDQNのReplayBufferの定義
class ReplayBuffer:
    def __init__(self, memory_size):
        self.memory_size = memory_size
        self.memory = deque([], maxlen = memory_size)
    
    def append(self, transition):
        self.memory.append(transition)
    
    def sample(self, batch_size):
        batch_indexes = np.random.randint(0, len(self.memory), size=batch_size)
        states      = np.array([self.memory[index]['state'] for index in batch_indexes])
        next_states = np.array([self.memory[index]['next_state'] for index in batch_indexes])
        rewards     = np.array([self.memory[index]['reward'] for index in batch_indexes])
        actions     = np.array([self.memory[index]['action'] for index in batch_indexes])
        dones   = np.array([self.memory[index]['done'] for index in batch_indexes])
        return {'states': states, 'next_states': next_states, 'rewards': rewards, 'actions': actions, 'dones': dones}

# %%
# 今回のReplayBuffer
class ReplayBuffer(object):
    """
    RNNを用いて訓練するのに適したリプレイバッファ
    """
    def __init__(self, capacity, observation_shape, action_dim):
        self.capacity = capacity

        self.observations = np.zeros((capacity, *observation_shape), dtype=np.uint8)
        self.actions = np.zeros((capacity, action_dim), dtype=np.float32)
        self.rewards = np.zeros((capacity, 1), dtype=np.float32)
        self.done = np.zeros((capacity, 1), dtype=np.bool)

        self.index = 0
        self.is_filled = False

    def push(self, observation, action, reward, done):
        """
        リプレイバッファに経験を追加する
        """
        self.observations[self.index] = observation
        self.actions[self.index] = action
        self.rewards[self.index] = reward
        self.done[self.index] = done

        # indexは巡回し, 最も古い経験を上書きする
        if self.index == self.capacity - 1:
            self.is_filled = True
        self.index = (self.index + 1) % self.capacity

    def sample(self, batch_size, chunk_length):
        """
        経験をリプレイバッファからサンプルします. （ほぼ）一様なサンプルです
        結果として返ってくるのは観測(画像), 行動, 報酬, 終了シグナルについての(batch_size, chunk_length, 各要素の次元)の配列です
        各バッチは連続した経験になっています
        注意: chunk_lengthをあまり大きな値にすると問題が発生する場合があります
        """
        episode_borders = np.where(self.done)[0]
        sampled_indexes = []
        for _ in range(batch_size):
            cross_border = True
            while cross_border:
                initial_index = np.random.randint(len(self) - chunk_length + 1)
                final_index = initial_index + chunk_length - 1
                cross_border = np.logical_and(initial_index <= episode_borders,
                                              episode_borders < final_index).any()#論理積
            sampled_indexes += list(range(initial_index, final_index + 1))

        sampled_observations = self.observations[sampled_indexes].reshape(
            batch_size, chunk_length, *self.observations.shape[1:])
        sampled_actions = self.actions[sampled_indexes].reshape(
            batch_size, chunk_length, self.actions.shape[1])
        sampled_rewards = self.rewards[sampled_indexes].reshape(
            batch_size, chunk_length, 1)
        sampled_done = self.done[sampled_indexes].reshape(
            batch_size, chunk_length, 1)
        return sampled_observations, sampled_actions, sampled_rewards, sampled_done

    def __len__(self):
        return self.capacity if self.is_filled else self.index

# %% [markdown]
# 次に観測の前処理を行う関数を実装します. これは簡単です. ちなみに, これもラッパーとして最初から適用してしまわないのは, リプレイバッファにはより容量の小さなnp.uint8の形式で保存しておきたいためです.

# %%
def preprocess_obs(obs):
    """
    画像の変換. [0, 255] -> [-0.5, 0.5]
    """
    obs = obs.astype(np.float32)
    normalized_obs = obs / 255.0 - 0.5
    return normalized_obs

# %% [markdown]
# Dreamerでは価値関数の学習を行いますが, このために通常のTD誤差ではなく, **TD(λ)をベースにしたλ-return**としてターゲット価値を計算し, それと現在の予測価値の誤差を用います. そのためにλ-returnを計算する関数をここで実装しておきます.

# %%
def lambda_target(rewards, values, gamma, lambda_):
    """
    価値関数の学習のためのλ-returnを計算します
    """
    V_lambda = torch.zeros_like(rewards, device=rewards.device)

    H = rewards.shape[0] - 1
    V_n = torch.zeros_like(rewards, device=rewards.device)
    V_n[H] = values[H]
    for n in range(1, H+1):
        # まずn-step returnを計算します
        # 注意: 系列が途中で終わってしまったら, 可能な中で最大のnを用いたn-stepを使います
        V_n[:-n] = (gamma ** n) * values[n:]
        for k in range(1, n+1):
            if k == n:
                V_n[:-n] += (gamma ** (n-1)) * rewards[k:]
            else:
                V_n[:-n] += (gamma ** (k-1)) * rewards[k:-n+k]

        # lambda_でn-step returnを重みづけてλ-returnを計算します
        if n == H:
            V_lambda += (lambda_ ** (H-1)) * V_n
        else:
            V_lambda += (1 - lambda_) * (lambda_ ** (n-1)) * V_n

    return V_lambda

# %% [markdown]
# ## 6.Dreamerの実装
#
# 続いてDreamerの実装です.Dreamerの実装では以下の3クラスは上で定義したRSSMの各クラスと同義ですので,
# 改めて定義はしておらず`RSSM`クラスを呼び出して使用することとします.
# * 状態遷移を担うクラス(TransitionModel）
# * 観測を復元するデコーダクラス（ObservationModel）
# * 報酬を予測するクラス（RewardModel）
#
#
# そのため,新たに定義するモデルは, 以下の３つのみになります.
# * 観測の画像をベクトルに変換するエンコーダクラス（Encoder）
# * 価値関数を計算するクラス（ValueModel）
# * 実際に行動を決定するクラス（ActionModel）

# %% [markdown]
# まずエンコーダを実装します. ここでは, CNN（Convolutional Neural Network）を用いて, 観測の画像をベクトルに変換します.

# %%
class Encoder(nn.Module):
    """
    (3, 64, 64)の画像を(1024,)のベクトルに変換するエンコーダ
    """
    def __init__(self):
        super(Encoder, self).__init__()
        self.cv1 = nn.Conv2d(3, 32, kernel_size=4, stride=2)
        self.cv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.cv3 = nn.Conv2d(64, 128, kernel_size=4, stride=2)
        self.cv4 = nn.Conv2d(128, 256, kernel_size=4, stride=2)

    def forward(self, obs):
        hidden = F.relu(self.cv1(obs))
        hidden = F.relu(self.cv2(hidden))
        hidden = F.relu(self.cv3(hidden))
        embedded_obs = F.relu(self.cv4(hidden)).reshape(hidden.size(0), -1)
        return embedded_obs

# %% [markdown]
# ここからがDreamerの中核となる部分で, RSSMの学習を通して獲得された低次元の状態表現の上でActor-Criticを行います.

# %% [markdown]
# 以下で, 価値関数を近似するValueモデル $v_{\phi}(s_{\tau})　\approx E_{q(.|s_{\tau})}(\sum_{\tau=t}^{t+H}(\gamma^{\tau-t}r_{\tau}) )$ を実装します. Q学習などで用いられる状態行動価値関数Q(s, a)ではなく, 状態価値関数V(s)であることに多少の注意が必要です.

# %%
class ValueModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から状態価値を出力する
    """
    def __init__(self, state_dim, rnn_hidden_dim, hidden_dim=400, act=F.elu):
        super(ValueModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, 1)
        self.act = act

    def forward(self, state, rnn_hidden):
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        state_value = self.fc4(hidden)
        return state_value

# %% [markdown]
# 最後です. 実際に行動を出力するActionモデル $a_{\tau} \sim q_{\delta}(a_{\tau}|s_{\tau})$ を実装します.
#
# Actionモデルは価値の見積もりを最大化することを目的とします.

# %%
class ActionModel(nn.Module):
    """
    低次元の状態表現(state_dim + rnn_hidden_dim)から行動を計算するクラス
    """
    def __init__(self, state_dim, rnn_hidden_dim, action_dim,
                 hidden_dim=400, act=F.elu, min_stddev=1e-4, init_stddev=5.0):
        super(ActionModel, self).__init__()
        self.fc1 = nn.Linear(state_dim + rnn_hidden_dim, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, hidden_dim)
        self.fc_mean = nn.Linear(hidden_dim, action_dim)
        self.fc_stddev = nn.Linear(hidden_dim, action_dim)
        self.act = act
        self.min_stddev = min_stddev
        self.init_stddev = np.log(np.exp(init_stddev) - 1)

    def forward(self, state, rnn_hidden, training=True):
        """
        training=Trueなら, NNのパラメータに関して微分可能な形の行動のサンプル（Reparametrizationによる）を返します
        training=Falseなら, 行動の確率分布の平均値を返します
        """
        hidden = self.act(self.fc1(torch.cat([state, rnn_hidden], dim=1)))
        hidden = self.act(self.fc2(hidden))
        hidden = self.act(self.fc3(hidden))
        hidden = self.act(self.fc4(hidden))

        # Dreamerの実装に合わせて少し平均と分散に対する簡単な変換が入っています
        mean = self.fc_mean(hidden)
        mean = 5.0 * torch.tanh(mean / 5.0)
        stddev = self.fc_stddev(hidden)
        stddev = F.softplus(stddev + self.init_stddev) + self.min_stddev

        if training:
            action = torch.tanh(Normal(mean, stddev).rsample())#微分可能にするためrsample()
        else:
            action = torch.tanh(mean)
        return action

# %% [markdown]
# 実装の詳細まで掴みきれなくとも, 個々のクラスが担っている役割が大雑把にでもわかっていただければ幸いです.

# %% [markdown]
# ## 7.エージェントの実装
#
# Dreamerでは行動を計算するために低次元の状態表現が必要で, この状態表現はRSSMを用いて計算されるため, テスト時もこの状態表現のためにRSSMによる推論を行い続ける必要があります.
#
# そのため, 先ほど実装したActionModelをそのまま使っても簡単には行動を決定できません.
#
# ここを扱いやすくするために, RSSMを使って低次元の状態表現を計算しつつ, 行動を決定するAgentクラスを実装します.

# %%
class Agent:
    """
    ActionModelに基づき行動を決定する. そのためにRSSMを用いて状態表現をリアルタイムで推論して維持するクラス
    """
    def __init__(self, encoder, rssm, action_model):
        self.encoder = encoder
        self.rssm = rssm
        self.action_model = action_model

        self.device = next(self.action_model.parameters()).device
        self.rnn_hidden = torch.zeros(1, rssm.rnn_hidden_dim, device=self.device)

    def __call__(self, obs, training=True):
        # preprocessを適用, PyTorchのためにChannel-Firstに変換
        obs = preprocess_obs(obs)
        obs = torch.as_tensor(obs, device=self.device)
        obs = obs.transpose(1, 2).transpose(0, 1).unsqueeze(0)

        with torch.no_grad():
            # 観測を低次元の表現に変換し, posteriorからのサンプルをActionModelに入力して行動を決定する
            embedded_obs = self.encoder(obs)
            state_posterior = self.rssm.posterior(self.rnn_hidden, embedded_obs)
            state = state_posterior.sample()
            action = self.action_model(state, self.rnn_hidden, training=training)

            # 次のステップのためにRNNの隠れ状態を更新しておく
            _, self.rnn_hidden = self.rssm.prior(self.rssm.reccurent(state, action, self.rnn_hidden))

        return action.squeeze().cpu().numpy()

    #RNNの隠れ状態をリセット
    def reset(self):
        self.rnn_hidden = torch.zeros(1, self.rssm.rnn_hidden_dim, device=self.device)

# %% [markdown]
# ## 8.ハイパーパラメータの設定と学習の準備
#
# ここまででDreamerの基本的な構成要素は実装が終わりました. あとはハイパーパラメータを設定し, モデルやリプレイバッファを宣言して学習の準備を整えます.

# %%
# リプレイバッファの宣言
buffer_capacity = 200000  # Colabのメモリの都合上, 元の実装より小さめにとっています
replay_buffer = ReplayBuffer(capacity=buffer_capacity,
                              observation_shape=env.observation_space.shape,
                              action_dim=env.action_space.n)

# モデルの宣言
state_dim = 30  # 確率的状態の次元
rnn_hidden_dim = 200  # 決定的状態（RNNの隠れ状態）の次元
#確率的状態の次元と決定的状態（RNNの隠れ状態）の次元は一致しなくて良い
encoder = Encoder().to(device)
rssm = RSSM(state_dim,env.action_space.n,rnn_hidden_dim, )
value_model = ValueModel(state_dim, rnn_hidden_dim).to(device)
action_model = ActionModel(state_dim, rnn_hidden_dim,
                             env.action_space.n).to(device)

# オプティマイザの宣言
model_lr = 6e-4  # encoder, rssm, obs_model, reward_modelの学習率
value_lr = 8e-5
action_lr = 8e-5
eps = 1e-4
model_params = (list(encoder.parameters()) +
                  list(rssm.transition.parameters()) +
                  list(rssm.observation.parameters()) +
                  list(rssm.reward.parameters()))
model_optimizer = torch.optim.Adam(model_params, lr=model_lr, eps=eps)
value_optimizer = torch.optim.Adam(value_model.parameters(), lr=value_lr, eps=eps)
action_optimizer = torch.optim.Adam(action_model.parameters(), lr=action_lr, eps=eps)

# その他ハイパーパラメータ
seed_episodes = 20   # 最初にランダム行動で探索するエピソード数
all_episodes = 300  # 学習全体のエピソード数（300ほどで, ある程度収束します）
test_interval = 10  # 何エピソードごとに探索ノイズなしのテストを行うか
model_save_interval = 20  # NNの重みを何エピソードごとに保存するか
collect_interval = 100  # 何回のNNの更新ごとに経験を集めるか（＝1エピソード経験を集めるごとに何回更新するか）

action_noise_var = 0.3  # 探索ノイズの強さ

# 基本的に1episodeからとれる経験の数が少ないのでseed_episodeからの経験のみで最低限の経験すら持ってこれないことがあるので注意
# chunk_lengthは特に注意
batch_size = 40
chunk_length = 15  # 1回の更新で用いる系列の長さ
imagination_horizon = 15  # Actor-Criticの更新のために, Dreamerで何ステップ先までの想像上の軌道を生成するか


gamma = 0.9  # 割引率
lambda_ = 0.95  # λ-returnのパラメータ
clip_grad_norm = 100  # gradient clippingの値
free_nats = 3  # KL誤差（RSSMのTransitionModelにおけるpriorとposteriorの間の誤差）がこの値以下の場合, 無視する
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if sys.path[0] == '':

# %% [markdown]
# ## 9.学習
# まず, 最初の数エピソードはランダムに行動して経験をリプレイバッファに貯めます.

# %%
env = make_env()
pid = 0

for episode in range(seed_episodes):
    obs = env.reset()
    done = False
    while not done:
        action = env.action_space.sample()
        env.addAction(pid = 0, action = action)
        env.addAction(pid = 1, action = random.randint(0, 5))
        next_obs, reward, done, _ = env.step()
        replay_buffer.push(obs, action, reward, done)
        obs = next_obs
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# 学習結果を確認するために, TensorBoardを立ち上げておきます.

# %%
log_dir = 'logs'
writer = SummaryWriter(log_dir)
#%tensorboard --logdir='./logs'

# %% [markdown]
# 以下がメインの学習ループです. それぞれのコメントを見て, 実装の内容を追ってください.
#
# 学習にはColab Proで3時間半ぐらいの時間がかかります.

# %%
env = make_env()
policy_enemy = Agent(encoder, rssm.transition, action_model)

for episode in range(seed_episodes, all_episodes):
    # -----------------------------
    #      経験を集める
    # -----------------------------
    start = time.time()
    # 行動を決定するためのエージェントを宣言
    policy = Agent(encoder, rssm.transition, action_model)

    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action = policy(obs)
        action_enemy = policy_enemy(obs, training=False)
        env.addAction(pid = 0, action = action)
        env.addAction(pid = 1, action = action_enemy)
        # 探索のためにガウス分布に従うノイズを加える(explaration noise)
        action += np.random.normal(0, np.sqrt(action_noise_var),
                                     env.action_space.n)
        next_obs, reward, done, _ = env.step()
        
        #リプレイバッファに観測, 行動, 報酬, doneを格納
        replay_buffer.push(obs, action, reward, done)
        
        obs = next_obs
        total_reward += reward

    # 訓練時の報酬と経過時間をログとして表示
    writer.add_scalar('total reward at train', total_reward, episode)
    print('episode [%4d/%4d] is collected. Total reward is %f' %
            (episode+1, all_episodes, total_reward))
    print('elasped time for interaction: %.2fs' % (time.time() - start))

    # NNのパラメータを更新する
    start = time.time()
    for update_step in range(collect_interval):
        # -------------------------------------------------------------------------------------
        #  RSSM(trainsition_model, obs_model, reward_model)の更新 - Dynamics learning
        # -------------------------------------------------------------------------------------
        observations, actions, rewards, _ = \
            replay_buffer.sample(batch_size, chunk_length)

        # 観測を前処理し, RNNを用いたPyTorchでの学習のためにTensorの次元を調整
        observations = preprocess_obs(observations)
        observations = torch.as_tensor(observations, device=device)
        observations = observations.transpose(3, 4).transpose(2, 3)
        observations = observations.transpose(0, 1)
        actions = torch.as_tensor(actions, device=device).transpose(0, 1)
        rewards = torch.as_tensor(rewards, device=device).transpose(0, 1)

        # 観測をエンコーダで低次元のベクトルに変換
        embedded_observations = encoder(
            observations.reshape(-1, 3, 64, 64)).view(chunk_length, batch_size, -1)

        # 低次元の状態表現を保持しておくためのTensorを定義
        states = torch.zeros(chunk_length, batch_size, state_dim, device=device)
        rnn_hiddens = torch.zeros(chunk_length, batch_size, rnn_hidden_dim, device=device)

        # 低次元の状態表現は最初はゼロ初期化（timestep１つ分）
        state = torch.zeros(batch_size, state_dim, device=device)
        rnn_hidden = torch.zeros(batch_size, rnn_hidden_dim, device=device)

        # 状態s_tの予測を行ってそのロスを計算する（priorとposteriorの間のKLダイバージェンス）
        kl_loss = 0
        for l in range(chunk_length-1):
            next_state_prior, next_state_posterior, rnn_hidden = \
                rssm.transition(state, actions[l], rnn_hidden, embedded_observations[l+1])
            state = next_state_posterior.rsample()
            states[l+1] = state
            rnn_hiddens[l+1] = rnn_hidden
            kl = kl_divergence(next_state_prior, next_state_posterior).sum(dim=1)
            kl_loss += kl.clamp(min=free_nats).mean()  # 原論文通り, KL誤差がfree_nats以下の時は無視
        kl_loss /= (chunk_length - 1)

        # states[0] and rnn_hiddens[0]はゼロ初期化なので以降では使わない
        # states, rnn_hiddensは低次元の状態表現
        states = states[1:]
        rnn_hiddens = rnn_hiddens[1:]

        # 観測を再構成, また, 報酬を予測
        flatten_states = states.view(-1, state_dim)
        flatten_rnn_hiddens = rnn_hiddens.view(-1, rnn_hidden_dim)
        recon_observations = rssm.observation(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 3, 64, 64)
        predicted_rewards = rssm.reward(flatten_states, flatten_rnn_hiddens).view(chunk_length-1, batch_size, 1)

        # 観測と報酬の予測誤差を計算
        obs_loss = 0.5 * F.mse_loss(recon_observations, observations[1:], reduction='none').mean([0, 1]).sum()
        reward_loss = 0.5 * F.mse_loss(predicted_rewards, rewards[:-1])

        # 以上のロスを合わせて勾配降下で更新する
        model_loss = kl_loss + obs_loss + reward_loss
        model_optimizer.zero_grad()
        model_loss.backward()
        clip_grad_norm_(model_params, clip_grad_norm)
        model_optimizer.step()

        # --------------------------------------------------
        #  Action Model, Value Modelの更新 - Behavior leaning
        # --------------------------------------------------
        # Actor-Criticのロスで他のモデルを更新することはないので勾配の流れを一度遮断
        # flatten_states, flatten_rnn_hiddensは RSSMから得られた低次元の状態表現を平坦化した値
        flatten_states = flatten_states.detach()
        flatten_rnn_hiddens = flatten_rnn_hiddens.detach()

        # DreamerにおけるActor-Criticの更新のために, 現在のモデルを用いた
        # 数ステップ先の未来の状態予測を保持するためのTensorを用意
        imaginated_states = torch.zeros(imagination_horizon + 1,
                                         *flatten_states.shape,
                                          device=flatten_states.device)
        imaginated_rnn_hiddens = torch.zeros(imagination_horizon + 1,
                                                *flatten_rnn_hiddens.shape,
                                                device=flatten_rnn_hiddens.device)

        #　未来予測をして想像上の軌道を作る前に, 最初の状態としては先ほどモデルの更新で使っていた
        # リプレイバッファからサンプルされた観測データを取り込んだ上で推論した状態表現を使う
        imaginated_states[0] = flatten_states
        imaginated_rnn_hiddens[0] = flatten_rnn_hiddens
        
        # open-loopで未来の状態予測を使い, 想像上の軌道を作る
        for h in range(1, imagination_horizon + 1):
            # 行動はActionModelで決定. この行動はモデルのパラメータに対して微分可能で,
            #　これを介してActionModelは更新される
            actions = action_model(flatten_states, flatten_rnn_hiddens)
            flatten_states_prior, flatten_rnn_hiddens = rssm.transition.prior(rssm.transition.reccurent(flatten_states,
                                                                   actions,
                                                                   flatten_rnn_hiddens))
            flatten_states = flatten_states_prior.rsample()
            imaginated_states[h] = flatten_states
            imaginated_rnn_hiddens[h] = flatten_rnn_hiddens

        # RSSMのreward_modelにより予測された架空の軌道に対する報酬を計算
        flatten_imaginated_states = imaginated_states.view(-1, state_dim)
        flatten_imaginated_rnn_hiddens = imaginated_rnn_hiddens.view(-1, rnn_hidden_dim)
        imaginated_rewards = \
            rssm.reward(flatten_imaginated_states,
                        flatten_imaginated_rnn_hiddens).view(imagination_horizon + 1, -1)
        imaginated_values = \
            value_model(flatten_imaginated_states,
                        flatten_imaginated_rnn_hiddens).view(imagination_horizon + 1, -1)

        # λ-returnのターゲットを計算(V_{\lambda}(s_{\tau})
        lambda_target_values = lambda_target(imaginated_rewards, imaginated_values, gamma, lambda_)

        # 価値関数の予測した価値が大きくなるようにActionModelを更新
        # PyTorchの基本は勾配降下だが, 今回は大きくしたいので-1をかける
        action_loss = -lambda_target_values.mean()
        action_optimizer.zero_grad()
        action_loss.backward()
        clip_grad_norm_(action_model.parameters(), clip_grad_norm)
        action_optimizer.step()
        
        # TD(λ)ベースの目的関数で価値関数を更新（価値関数のみを学習するため，学習しない変数のグラフは切っている. )
        imaginated_values = value_model(flatten_imaginated_states.detach(), flatten_imaginated_rnn_hiddens.detach()).view(imagination_horizon + 1, -1)        
        value_loss = 0.5 * F.mse_loss(imaginated_values, lambda_target_values.detach())
        value_optimizer.zero_grad()
        value_loss.backward()
        clip_grad_norm_(value_model.parameters(), clip_grad_norm)
        value_optimizer.step()

        # ログをTensorBoardに出力
        print('update_step: %3d model loss: %.5f, kl_loss: %.5f, '
             'obs_loss: %.5f, reward_loss: %.5f, '
             'value_loss: %.5f action_loss: %.5f'
                % (update_step + 1, model_loss.item(), kl_loss.item(),
                    obs_loss.item(), reward_loss.item(),
                    value_loss.item(), action_loss.item()))
        total_update_step = episode * collect_interval + update_step
        writer.add_scalar('model loss', model_loss.item(), total_update_step)
        writer.add_scalar('kl loss', kl_loss.item(), total_update_step)
        writer.add_scalar('obs loss', obs_loss.item(), total_update_step)
        writer.add_scalar('reward loss', reward_loss.item(), total_update_step)
        writer.add_scalar('value loss', value_loss.item(), total_update_step)
        writer.add_scalar('action loss', action_loss.item(), total_update_step)

    print('elasped time for update: %.2fs' % (time.time() - start))

    if (episode + 1) % 10 == 0:
        env.renderToGif(pid = 0, path = path + "/result/DreamerEpisode" + str(episode))
        # 敵を同期
        policy_enemy = copy.deepcopy(policy)
        

    # --------------------------------------------------------------
    #    テストフェーズ. 探索ノイズなしでの性能を評価する
    # --------------------------------------------------------------
    if (episode + 1) % test_interval == 0:
        policy = Agent(encoder, rssm.transition, action_model)
        start = time.time()
        obs = env.reset()
        done = False
        total_reward = 0
        while not done:
            action = policy(obs, training=False)
            action_enemy = policy_enemy(obs, training=False)

            env.addAction(pid = 0, action = action)
            env.addAction(pid = 1, action = action_enemy)

            obs, reward, done, _ = env.step()
            total_reward += reward

        writer.add_scalar('total reward at test', total_reward, episode)
        print('Total test reward at episode [%4d/%4d] is %f' %
                (episode+1, all_episodes, total_reward))
        print('elasped time for test: %.2fs' % (time.time() - start))

    if (episode + 1) % model_save_interval == 0:
        # 定期的に学習済みモデルのパラメータを保存する
        model_log_dir = os.path.join(log_dir, 'episode_%04d' % (episode + 1))
        os.makedirs(model_log_dir)
        torch.save(encoder.state_dict(), os.path.join(model_log_dir, 'encoder.pth'))
        torch.save(rssm.transition.state_dict(), os.path.join(model_log_dir, 'rssm.pth'))
        torch.save(rssm.observation.state_dict(), os.path.join(model_log_dir, 'obs_model.pth'))
        torch.save(rssm.reward.state_dict(), os.path.join(model_log_dir, 'reward_model.pth'))
        torch.save(value_model.state_dict(), os.path.join(model_log_dir, 'value_model.pth'))
        torch.save(action_model.state_dict(), os.path.join(model_log_dir, 'action_model.pth'))

writer.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# update_step:  88 model loss: 19.32774, kl_loss: 4.26208, obs_loss: 14.05737, reward_loss: 1.00828, value_loss: 3.57484 action_loss: 29.34588
# update_step:  89 model loss: 20.73034, kl_loss: 4.29701, obs_loss: 15.22430, reward_loss: 1.20902, value_loss: 2.89100 action_loss: 29.20293
# update_step:  90 model loss: 22.64560, kl_loss: 4.32168, obs_loss: 17.54768, reward_loss: 0.77625, value_loss: 2.42231 action_loss: 28.90589
# update_step:  91 model loss: 26.04962, kl_loss: 4.38116, obs_loss: 21.11440, reward_loss: 0.55405, value_loss: 2.57432 action_loss: 31.22308
# update_step:  92 model loss: 22.57973, kl_loss: 4.38976, obs_loss: 17.24019, reward_loss: 0.94978, value_loss: 2.87528 action_loss: 29.19276
# update_step:  93 model loss: 24.50870, kl_loss: 4.40998, obs_loss: 19.27481, reward_loss: 0.82392, value_loss: 2.50564 action_loss: 30.45751
# update_step:  94 model loss: 23.77971, kl_loss: 4.29353, obs_loss: 18.41227, reward_loss: 1.07391, value_loss: 2.76552 action_loss: 28.99381
# update_step:  95 model loss: 20.79132, kl_loss: 4.22418, obs_loss: 15.48755, reward_loss: 1.07959, value_loss: 2.16496 action_loss: 27.01193
# update_step:  96 model loss: 19.79385, kl_loss: 4.15280, obs_loss: 14.66600, reward_loss: 0.97505, value_loss: 1.82931 action_loss: 28.95094
# update_step:  97 model loss: 20.12933, kl_loss: 4.21004, obs_loss: 15.14853, reward_loss: 0.77076, value_loss: 1.74120 action_loss: 30.40664
# update_step:  98 model loss: 21.73509, kl_loss: 4.18654, obs_loss: 16.49273, reward_loss: 1.05582, value_loss: 2.81074 action_loss: 29.84303
# update_step:  99 model loss: 17.78222, kl_loss: 4.09853, obs_loss: 12.69552, reward_loss: 0.98817, value_loss: 2.41855 action_loss: 31.59164
# update_step: 100 model loss: 26.03627, kl_loss: 4.42848, obs_loss: 20.99213, reward_loss: 0.61566, value_loss: 3.43374 action_loss: 31.51111
# elasped time for update: 32.98s
# episode [  27/ 300] is collected. Total reward is -1711.560000
# elasped time for interaction: 4.24s
# update_step:   1 model loss: 28.97116, kl_loss: 5.37209, obs_loss: 22.43885, reward_loss: 1.16023, value_loss: 2.09872 action_loss: 30.61903
# update_step:   2 model loss: 27.63352, kl_loss: 4.64927, obs_loss: 21.97544, reward_loss: 1.00881, value_loss: 1.91765 action_loss: 30.99396
# update_step:   3 model loss: 22.77350, kl_loss: 4.22966, obs_loss: 17.36645, reward_loss: 1.17738, value_loss: 2.26983 action_loss: 30.18062
# update_step:   4 model loss: 30.09787, kl_loss: 4.33540, obs_loss: 24.19252, reward_loss: 1.56996, value_loss: 2.51395 action_loss: 32.77159
# update_step:   5 model loss: 27.31843, kl_loss: 4.23184, obs_loss: 21.93397, reward_loss: 1.15262, value_loss: 2.41604 action_loss: 29.36515
# update_step:   6 model loss: 22.27967, kl_loss: 4.35897, obs_loss: 17.13409, reward_loss: 0.78661, value_loss: 3.45672 action_loss: 28.82823
# update_step:   7 model loss: 24.99314, kl_loss: 4.40798, obs_loss: 19.52595, reward_loss: 1.05922, value_loss: 2.40486 action_loss: 29.58449
# update_step:   8 model loss: 26.47591, kl_loss: 4.47197, obs_loss: 21.25122, reward_loss: 0.75272, value_loss: 2.90553 action_loss: 29.93706
# update_step:   9 model loss: 24.26173, kl_loss: 4.11266, obs_loss: 19.07059, reward_loss: 1.07847, value_loss: 2.38843 action_loss: 29.98314
# update_step:  10 model loss: 18.22053, kl_loss: 3.99218, obs_loss: 12.63943, reward_loss: 1.58892, value_loss: 1.53063 action_loss: 27.01670
# update_step:  11 model loss: 24.67233, kl_loss: 4.46080, obs_loss: 19.10473, reward_loss: 1.10680, value_loss: 2.03356 action_loss: 29.48285
# update_step:  12 model loss: 23.86951, kl_loss: 4.51016, obs_loss: 18.52045, reward_loss: 0.83891, value_loss: 2.00770 action_loss: 28.05488
# update_step:  13 model loss: 24.14952, kl_loss: 4.42319, obs_loss: 18.95167, reward_loss: 0.77467, value_loss: 3.03880 action_loss: 30.75012
# update_step:  14 model loss: 21.03792, kl_loss: 4.13124, obs_loss: 15.32226, reward_loss: 1.58441, value_loss: 2.23330 action_loss: 30.46550
# update_step:  15 model loss: 25.72572, kl_loss: 4.26540, obs_loss: 20.64922, reward_loss: 0.81110, value_loss: 2.57191 action_loss: 32.82114
# update_step:  16 model loss: 22.24865, kl_loss: 4.30381, obs_loss: 16.76433, reward_loss: 1.18051, value_loss: 2.70484 action_loss: 30.18228
# update_step:  17 model loss: 21.97993, kl_loss: 4.26923, obs_loss: 16.81900, reward_loss: 0.89170, value_loss: 3.13882 action_loss: 31.48840
# update_step:  18 model loss: 18.66312, kl_loss: 4.10181, obs_loss: 13.81043, reward_loss: 0.75087, value_loss: 2.27215 action_loss: 28.63842
# update_step:  19 model loss: 22.59190, kl_loss: 4.24279, obs_loss: 17.15916, reward_loss: 1.18995, value_loss: 1.94753 action_loss: 27.68024
# update_step:  20 model loss: 23.94446, kl_loss: 4.28332, obs_loss: 18.97749, reward_loss: 0.68365, value_loss: 2.49775 action_loss: 28.91851
# update_step:  21 model loss: 22.99161, kl_loss: 4.27352, obs_loss: 17.76686, reward_loss: 0.95123, value_loss: 2.54753 action_loss: 29.87227
# update_step:  22 model loss: 22.23925, kl_loss: 4.37260, obs_loss: 16.97597, reward_loss: 0.89068, value_loss: 2.75928 action_loss: 27.13515
# update_step:  23 model loss: 21.96861, kl_loss: 4.31271, obs_loss: 16.51340, reward_loss: 1.14250, value_loss: 2.85990 action_loss: 28.05219
# update_step:  24 model loss: 19.54877, kl_loss: 4.18777, obs_loss: 14.18629, reward_loss: 1.17472, value_loss: 2.17814 action_loss: 26.95030
# update_step:  25 model loss: 23.60141, kl_loss: 4.44297, obs_loss: 18.03548, reward_loss: 1.12296, value_loss: 3.17003 action_loss: 27.56339
# update_step:  26 model loss: 21.75684, kl_loss: 4.38116, obs_loss: 16.18563, reward_loss: 1.19005, value_loss: 2.16980 action_loss: 26.61263
# update_step:  27 model loss: 20.50948, kl_loss: 4.36502, obs_loss: 15.36191, reward_loss: 0.78255, value_loss: 1.41530 action_loss: 27.18484
# update_step:  28 model loss: 23.91014, kl_loss: 4.29717, obs_loss: 18.66903, reward_loss: 0.94394, value_loss: 1.71967 action_loss: 27.98875
# update_step:  29 model loss: 23.87389, kl_loss: 4.36734, obs_loss: 18.51055, reward_loss: 0.99600, value_loss: 1.64804 action_loss: 29.41698
# update_step:  30 model loss: 23.41123, kl_loss: 4.25932, obs_loss: 18.39816, reward_loss: 0.75375, value_loss: 3.29884 action_loss: 29.10449
# update_step:  31 model loss: 20.05331, kl_loss: 4.21785, obs_loss: 15.08118, reward_loss: 0.75428, value_loss: 2.36128 action_loss: 29.58257
# update_step:  32 model loss: 22.31281, kl_loss: 4.31364, obs_loss: 16.94942, reward_loss: 1.04975, value_loss: 3.65258 action_loss: 29.68657
# update_step:  33 model loss: 21.95158, kl_loss: 4.28713, obs_loss: 16.69023, reward_loss: 0.97422, value_loss: 4.09836 action_loss: 30.82855
# update_step:  34 model loss: 23.72135, kl_loss: 4.40765, obs_loss: 18.28172, reward_loss: 1.03198, value_loss: 2.42286 action_loss: 27.85142
# update_step:  35 model loss: 21.92587, kl_loss: 4.27745, obs_loss: 16.59595, reward_loss: 1.05248, value_loss: 3.30527 action_loss: 30.94716
# update_step:  36 model loss: 20.12523, kl_loss: 4.19636, obs_loss: 14.57343, reward_loss: 1.35544, value_loss: 1.45500 action_loss: 27.89172
# update_step:  37 model loss: 22.32267, kl_loss: 4.31460, obs_loss: 17.09844, reward_loss: 0.90963, value_loss: 1.50440 action_loss: 27.88003
# update_step:  38 model loss: 19.08922, kl_loss: 4.21360, obs_loss: 13.68701, reward_loss: 1.18861, value_loss: 1.22073 action_loss: 28.17610
# update_step:  39 model loss: 20.71159, kl_loss: 4.32343, obs_loss: 15.43254, reward_loss: 0.95562, value_loss: 2.07008 action_loss: 27.60645
# update_step:  40 model loss: 19.81225, kl_loss: 4.20424, obs_loss: 14.73284, reward_loss: 0.87517, value_loss: 2.07246 action_loss: 27.77877
# update_step:  41 model loss: 21.13697, kl_loss: 4.48167, obs_loss: 15.79008, reward_loss: 0.86522, value_loss: 2.97001 action_loss: 26.30157
# update_step:  42 model loss: 19.71053, kl_loss: 4.24261, obs_loss: 14.36715, reward_loss: 1.10078, value_loss: 2.24641 action_loss: 25.77075
# update_step:  43 model loss: 19.86486, kl_loss: 4.19877, obs_loss: 14.73528, reward_loss: 0.93082, value_loss: 2.43396 action_loss: 27.75117
# update_step:  44 model loss: 23.17248, kl_loss: 4.44117, obs_loss: 17.99960, reward_loss: 0.73171, value_loss: 2.06754 action_loss: 26.94363
# update_step:  45 model loss: 18.63560, kl_loss: 4.16528, obs_loss: 13.39647, reward_loss: 1.07384, value_loss: 1.39533 action_loss: 27.69108
# update_step:  46 model loss: 21.98521, kl_loss: 4.39587, obs_loss: 16.53623, reward_loss: 1.05310, value_loss: 1.38061 action_loss: 30.06111
# update_step:  47 model loss: 19.46204, kl_loss: 4.23427, obs_loss: 13.75116, reward_loss: 1.47661, value_loss: 1.94038 action_loss: 27.58470
# update_step:  48 model loss: 19.07574, kl_loss: 4.19326, obs_loss: 13.53069, reward_loss: 1.35179, value_loss: 2.22886 action_loss: 28.45173
# update_step:  49 model loss: 19.49280, kl_loss: 4.27660, obs_loss: 14.34815, reward_loss: 0.86804, value_loss: 5.07742 action_loss: 28.01078
# update_step:  50 model loss: 21.12500, kl_loss: 4.38352, obs_loss: 15.86977, reward_loss: 0.87171, value_loss: 5.08644 action_loss: 30.06768
# update_step:  51 model loss: 20.36341, kl_loss: 4.27603, obs_loss: 15.02308, reward_loss: 1.06429, value_loss: 5.09911 action_loss: 30.52752
# update_step:  52 model loss: 17.00871, kl_loss: 4.03792, obs_loss: 11.83269, reward_loss: 1.13811, value_loss: 2.56678 action_loss: 28.49791
# update_step:  53 model loss: 15.27668, kl_loss: 3.97751, obs_loss: 9.97623, reward_loss: 1.32294, value_loss: 2.19605 action_loss: 27.93324
# update_step:  54 model loss: 20.38366, kl_loss: 4.39601, obs_loss: 14.72647, reward_loss: 1.26118, value_loss: 1.35258 action_loss: 28.64838
# update_step:  55 model loss: 19.51282, kl_loss: 4.24166, obs_loss: 14.31822, reward_loss: 0.95294, value_loss: 1.39363 action_loss: 26.73602
# update_step:  56 model loss: 23.00155, kl_loss: 4.48854, obs_loss: 17.77254, reward_loss: 0.74047, value_loss: 2.14511 action_loss: 27.79238
# update_step:  57 model loss: 18.10426, kl_loss: 4.19991, obs_loss: 12.66340, reward_loss: 1.24094, value_loss: 3.33969 action_loss: 28.05504
# update_step:  58 model loss: 20.84462, kl_loss: 4.24170, obs_loss: 15.23460, reward_loss: 1.36832, value_loss: 4.04578 action_loss: 29.84367
# update_step:  59 model loss: 21.85930, kl_loss: 4.32351, obs_loss: 16.49028, reward_loss: 1.04551, value_loss: 3.84045 action_loss: 26.74793
# update_step:  60 model loss: 21.06163, kl_loss: 4.36369, obs_loss: 15.68110, reward_loss: 1.01684, value_loss: 2.39934 action_loss: 28.39782
# update_step:  61 model loss: 20.98985, kl_loss: 4.46190, obs_loss: 15.47233, reward_loss: 1.05562, value_loss: 2.16196 action_loss: 29.04314
# update_step:  62 model loss: 19.26123, kl_loss: 4.28719, obs_loss: 13.77394, reward_loss: 1.20011, value_loss: 1.74776 action_loss: 29.05780
# update_step:  63 model loss: 21.66541, kl_loss: 4.23689, obs_loss: 16.59007, reward_loss: 0.83845, value_loss: 1.96178 action_loss: 29.96811
# update_step:  64 model loss: 18.29940, kl_loss: 4.06445, obs_loss: 13.12128, reward_loss: 1.11367, value_loss: 2.04304 action_loss: 30.01952
# update_step:  65 model loss: 23.42250, kl_loss: 4.22608, obs_loss: 17.96159, reward_loss: 1.23483, value_loss: 3.23688 action_loss: 28.19163
# update_step:  66 model loss: 21.44493, kl_loss: 4.30838, obs_loss: 16.14947, reward_loss: 0.98708, value_loss: 2.90210 action_loss: 28.78708
# update_step:  67 model loss: 21.35711, kl_loss: 4.24880, obs_loss: 16.18415, reward_loss: 0.92415, value_loss: 2.70394 action_loss: 28.26796
# update_step:  68 model loss: 21.57723, kl_loss: 4.34132, obs_loss: 16.45593, reward_loss: 0.77998, value_loss: 2.98787 action_loss: 29.47311
# update_step:  69 model loss: 19.63240, kl_loss: 4.20373, obs_loss: 14.41651, reward_loss: 1.01216, value_loss: 2.54256 action_loss: 28.86590
# update_step:  70 model loss: 20.22180, kl_loss: 4.37495, obs_loss: 14.78295, reward_loss: 1.06391, value_loss: 2.28768 action_loss: 30.69468
# update_step:  71 model loss: 18.40867, kl_loss: 4.31169, obs_loss: 13.05022, reward_loss: 1.04677, value_loss: 2.07807 action_loss: 28.32968
# update_step:  72 model loss: 20.73689, kl_loss: 4.36103, obs_loss: 15.03021, reward_loss: 1.34564, value_loss: 2.32014 action_loss: 31.34364
# update_step:  73 model loss: 24.70241, kl_loss: 4.56133, obs_loss: 19.24866, reward_loss: 0.89242, value_loss: 1.86107 action_loss: 32.44251
# update_step:  74 model loss: 21.08747, kl_loss: 4.42564, obs_loss: 15.50102, reward_loss: 1.16081, value_loss: 2.73618 action_loss: 30.19463
# update_step:  75 model loss: 15.95513, kl_loss: 4.09341, obs_loss: 10.93432, reward_loss: 0.92740, value_loss: 3.70938 action_loss: 27.15653
# update_step:  76 model loss: 20.07543, kl_loss: 4.29753, obs_loss: 14.64111, reward_loss: 1.13679, value_loss: 4.53175 action_loss: 28.87596
# update_step:  77 model loss: 21.56082, kl_loss: 4.33350, obs_loss: 16.25069, reward_loss: 0.97662, value_loss: 7.32535 action_loss: 26.77325
# update_step:  78 model loss: 23.17117, kl_loss: 4.39235, obs_loss: 17.87019, reward_loss: 0.90862, value_loss: 5.59991 action_loss: 25.75279
# update_step:  79 model loss: 16.34276, kl_loss: 4.02007, obs_loss: 11.34090, reward_loss: 0.98179, value_loss: 4.38481 action_loss: 27.00791
# update_step:  80 model loss: 17.81797, kl_loss: 4.16165, obs_loss: 12.58702, reward_loss: 1.06930, value_loss: 3.57275 action_loss: 27.62218
# update_step:  81 model loss: 22.17765, kl_loss: 4.36061, obs_loss: 16.89168, reward_loss: 0.92536, value_loss: 2.26597 action_loss: 26.91143
# update_step:  82 model loss: 17.24882, kl_loss: 4.16442, obs_loss: 12.14392, reward_loss: 0.94047, value_loss: 2.03388 action_loss: 27.47840
# update_step:  83 model loss: 19.83917, kl_loss: 4.35829, obs_loss: 14.18733, reward_loss: 1.29355, value_loss: 0.91405 action_loss: 25.91414
# update_step:  84 model loss: 18.93772, kl_loss: 4.32563, obs_loss: 13.65481, reward_loss: 0.95728, value_loss: 2.22664 action_loss: 30.09968
# update_step:  85 model loss: 18.41182, kl_loss: 4.16625, obs_loss: 13.23578, reward_loss: 1.00980, value_loss: 1.95551 action_loss: 27.47033
# update_step:  86 model loss: 20.14693, kl_loss: 4.33391, obs_loss: 15.21195, reward_loss: 0.60107, value_loss: 3.69424 action_loss: 28.14568
# update_step:  87 model loss: 22.93969, kl_loss: 4.35955, obs_loss: 17.96284, reward_loss: 0.61730, value_loss: 3.12896 action_loss: 27.13433
# update_step:  88 model loss: 15.51904, kl_loss: 4.02385, obs_loss: 10.16379, reward_loss: 1.33140, value_loss: 4.80654 action_loss: 27.30763
# update_step:  89 model loss: 21.19214, kl_loss: 4.39529, obs_loss: 15.63313, reward_loss: 1.16372, value_loss: 3.06638 action_loss: 28.77536
# update_step:  90 model loss: 18.69801, kl_loss: 4.21645, obs_loss: 13.38610, reward_loss: 1.09546, value_loss: 2.10456 action_loss: 27.56413
# update_step:  91 model loss: 18.47303, kl_loss: 4.19422, obs_loss: 13.52653, reward_loss: 0.75228, value_loss: 1.69363 action_loss: 28.30375
# update_step:  92 model loss: 20.56816, kl_loss: 4.28384, obs_loss: 15.67355, reward_loss: 0.61077, value_loss: 1.37313 action_loss: 27.64956
# update_step:  93 model loss: 21.49076, kl_loss: 4.40958, obs_loss: 16.05068, reward_loss: 1.03049, value_loss: 1.22303 action_loss: 27.63131
# update_step:  94 model loss: 17.67922, kl_loss: 4.14792, obs_loss: 12.45038, reward_loss: 1.08092, value_loss: 1.62006 action_loss: 28.86297
# update_step:  95 model loss: 24.52955, kl_loss: 4.38663, obs_loss: 19.48550, reward_loss: 0.65742, value_loss: 1.76581 action_loss: 28.49895
# update_step:  96 model loss: 20.84073, kl_loss: 4.35777, obs_loss: 15.66984, reward_loss: 0.81312, value_loss: 1.90455 action_loss: 27.26424
# update_step:  97 model loss: 21.74891, kl_loss: 4.44550, obs_loss: 16.57489, reward_loss: 0.72852, value_loss: 1.34572 action_loss: 25.09350
# update_step:  98 model loss: 15.54275, kl_loss: 4.08061, obs_loss: 10.19138, reward_loss: 1.27076, value_loss: 1.28862 action_loss: 25.20663
# update_step:  99 model loss: 18.28715, kl_loss: 4.27329, obs_loss: 13.10109, reward_loss: 0.91278, value_loss: 1.63187 action_loss: 29.52662
# update_step: 100 model loss: 19.64935, kl_loss: 4.19315, obs_loss: 14.57925, reward_loss: 0.87696, value_loss: 2.26890 action_loss: 29.39291
# elasped time for update: 32.83s
# episode [  28/ 300] is collected. Total reward is -2240.608000
# elasped time for interaction: 4.14s
# update_step:   1 model loss: 30.92610, kl_loss: 4.22851, obs_loss: 25.61188, reward_loss: 1.08572, value_loss: 1.33364 action_loss: 28.80017
# update_step:   2 model loss: 23.75438, kl_loss: 4.25198, obs_loss: 18.34267, reward_loss: 1.15973, value_loss: 1.22706 action_loss: 27.99233
# update_step:   3 model loss: 24.53407, kl_loss: 4.38489, obs_loss: 19.07816, reward_loss: 1.07102, value_loss: 1.86318 action_loss: 26.40010
# update_step:   4 model loss: 25.37206, kl_loss: 4.33703, obs_loss: 20.12681, reward_loss: 0.90821, value_loss: 2.40417 action_loss: 28.54543
# update_step:   5 model loss: 23.71881, kl_loss: 4.18130, obs_loss: 18.62732, reward_loss: 0.91019, value_loss: 1.89652 action_loss: 27.79364
# update_step:   6 model loss: 24.85879, kl_loss: 4.27614, obs_loss: 19.36674, reward_loss: 1.21592, value_loss: 1.62283 action_loss: 27.69575
# update_step:   7 model loss: 26.83436, kl_loss: 4.43161, obs_loss: 21.49289, reward_loss: 0.90987, value_loss: 1.57152 action_loss: 26.45570
# update_step:   8 model loss: 24.40117, kl_loss: 4.47017, obs_loss: 19.08287, reward_loss: 0.84812, value_loss: 1.13790 action_loss: 26.53159
# update_step:   9 model loss: 24.49201, kl_loss: 4.46887, obs_loss: 19.04996, reward_loss: 0.97319, value_loss: 1.93914 action_loss: 24.90247
# update_step:  10 model loss: 23.32135, kl_loss: 4.40210, obs_loss: 18.09635, reward_loss: 0.82290, value_loss: 2.45838 action_loss: 26.45068
# update_step:  11 model loss: 21.86154, kl_loss: 4.50625, obs_loss: 16.31344, reward_loss: 1.04185, value_loss: 2.50588 action_loss: 24.93721
# update_step:  12 model loss: 22.07965, kl_loss: 4.37455, obs_loss: 16.69984, reward_loss: 1.00526, value_loss: 2.05485 action_loss: 24.35439
# update_step:  13 model loss: 22.79344, kl_loss: 4.36911, obs_loss: 16.88213, reward_loss: 1.54221, value_loss: 2.39545 action_loss: 24.70524
# update_step:  14 model loss: 22.48719, kl_loss: 4.36918, obs_loss: 16.92865, reward_loss: 1.18935, value_loss: 2.20370 action_loss: 26.62653
# update_step:  15 model loss: 22.25901, kl_loss: 4.28343, obs_loss: 17.08206, reward_loss: 0.89353, value_loss: 1.85466 action_loss: 25.08282
# update_step:  16 model loss: 23.33714, kl_loss: 4.39191, obs_loss: 17.83009, reward_loss: 1.11514, value_loss: 2.08483 action_loss: 25.38424
# update_step:  17 model loss: 19.19046, kl_loss: 4.17844, obs_loss: 14.01444, reward_loss: 0.99758, value_loss: 1.80333 action_loss: 26.32399
# update_step:  18 model loss: 22.90929, kl_loss: 4.22449, obs_loss: 17.35485, reward_loss: 1.32995, value_loss: 2.88796 action_loss: 27.06514
# update_step:  19 model loss: 20.96251, kl_loss: 4.21361, obs_loss: 15.67046, reward_loss: 1.07844, value_loss: 4.42755 action_loss: 27.47972
# update_step:  20 model loss: 20.61724, kl_loss: 4.27946, obs_loss: 15.36215, reward_loss: 0.97562, value_loss: 6.52020 action_loss: 28.99309
# update_step:  21 model loss: 19.35355, kl_loss: 4.22551, obs_loss: 14.16325, reward_loss: 0.96478, value_loss: 6.82796 action_loss: 28.85926
# update_step:  22 model loss: 20.10901, kl_loss: 4.23360, obs_loss: 14.89937, reward_loss: 0.97603, value_loss: 5.12647 action_loss: 28.40000
# update_step:  23 model loss: 22.04002, kl_loss: 4.55054, obs_loss: 16.55869, reward_loss: 0.93079, value_loss: 6.46856 action_loss: 30.89704
# update_step:  24 model loss: 18.19309, kl_loss: 4.16686, obs_loss: 12.65590, reward_loss: 1.37033, value_loss: 6.04526 action_loss: 29.99351
# update_step:  25 model loss: 18.78258, kl_loss: 4.26247, obs_loss: 13.35561, reward_loss: 1.16451, value_loss: 4.70947 action_loss: 29.03140
# update_step:  26 model loss: 22.26036, kl_loss: 4.42528, obs_loss: 16.52191, reward_loss: 1.31318, value_loss: 3.21742 action_loss: 30.06796
# update_step:  27 model loss: 19.59993, kl_loss: 4.27248, obs_loss: 14.02023, reward_loss: 1.30723, value_loss: 2.83838 action_loss: 28.13320
# update_step:  28 model loss: 19.97280, kl_loss: 4.22815, obs_loss: 14.51704, reward_loss: 1.22762, value_loss: 1.61029 action_loss: 28.28313
# update_step:  29 model loss: 15.46001, kl_loss: 3.99840, obs_loss: 10.11738, reward_loss: 1.34422, value_loss: 1.41409 action_loss: 29.82905
# update_step:  30 model loss: 19.75322, kl_loss: 4.39695, obs_loss: 14.48579, reward_loss: 0.87048, value_loss: 1.61274 action_loss: 28.97951
# update_step:  31 model loss: 20.13915, kl_loss: 4.31556, obs_loss: 14.80088, reward_loss: 1.02272, value_loss: 1.86410 action_loss: 29.01093
# update_step:  32 model loss: 19.01831, kl_loss: 4.16054, obs_loss: 13.68663, reward_loss: 1.17113, value_loss: 1.79584 action_loss: 29.36761
# update_step:  33 model loss: 21.17867, kl_loss: 4.38875, obs_loss: 16.04135, reward_loss: 0.74858, value_loss: 2.25749 action_loss: 30.04988
# update_step:  34 model loss: 21.97327, kl_loss: 4.36583, obs_loss: 16.44831, reward_loss: 1.15913, value_loss: 2.86683 action_loss: 30.56000
# update_step:  35 model loss: 20.80498, kl_loss: 4.42604, obs_loss: 15.82025, reward_loss: 0.55869, value_loss: 3.10979 action_loss: 31.28682
# update_step:  36 model loss: 19.06733, kl_loss: 4.28762, obs_loss: 13.93374, reward_loss: 0.84597, value_loss: 2.97252 action_loss: 31.06315
# update_step:  37 model loss: 21.46939, kl_loss: 4.29546, obs_loss: 16.07404, reward_loss: 1.09988, value_loss: 2.69964 action_loss: 29.84367
# update_step:  38 model loss: 19.94500, kl_loss: 4.26979, obs_loss: 14.67307, reward_loss: 1.00215, value_loss: 2.23916 action_loss: 30.54681
# update_step:  39 model loss: 20.59265, kl_loss: 4.28371, obs_loss: 15.36856, reward_loss: 0.94037, value_loss: 2.79765 action_loss: 29.20579
# update_step:  40 model loss: 19.57118, kl_loss: 4.25090, obs_loss: 14.23147, reward_loss: 1.08880, value_loss: 1.81258 action_loss: 26.57439
# update_step:  41 model loss: 19.10998, kl_loss: 4.23593, obs_loss: 13.34276, reward_loss: 1.53129, value_loss: 1.79347 action_loss: 29.47778
# update_step:  42 model loss: 21.36214, kl_loss: 4.45293, obs_loss: 15.85773, reward_loss: 1.05148, value_loss: 1.75038 action_loss: 29.91261
# update_step:  43 model loss: 20.44095, kl_loss: 4.35962, obs_loss: 15.07041, reward_loss: 1.01092, value_loss: 1.96899 action_loss: 28.89271
# update_step:  44 model loss: 18.50057, kl_loss: 4.38374, obs_loss: 13.24446, reward_loss: 0.87236, value_loss: 1.66710 action_loss: 27.43410
# update_step:  45 model loss: 17.58449, kl_loss: 4.31077, obs_loss: 12.30955, reward_loss: 0.96417, value_loss: 1.59037 action_loss: 29.63606
# update_step:  46 model loss: 20.47274, kl_loss: 4.38121, obs_loss: 15.07723, reward_loss: 1.01430, value_loss: 4.09452 action_loss: 31.51370
# update_step:  47 model loss: 17.81889, kl_loss: 4.32505, obs_loss: 12.47125, reward_loss: 1.02259, value_loss: 3.15637 action_loss: 29.70298
# update_step:  48 model loss: 20.40979, kl_loss: 4.43075, obs_loss: 15.14180, reward_loss: 0.83724, value_loss: 2.94453 action_loss: 32.61809
# update_step:  49 model loss: 19.01811, kl_loss: 4.26535, obs_loss: 13.79394, reward_loss: 0.95883, value_loss: 2.83445 action_loss: 31.89935
# update_step:  50 model loss: 19.29185, kl_loss: 4.33741, obs_loss: 13.97956, reward_loss: 0.97488, value_loss: 3.54119 action_loss: 33.46598
# update_step:  51 model loss: 18.75063, kl_loss: 4.20350, obs_loss: 13.32415, reward_loss: 1.22298, value_loss: 2.92977 action_loss: 32.58361
# update_step:  52 model loss: 20.36340, kl_loss: 4.33855, obs_loss: 15.24994, reward_loss: 0.77491, value_loss: 2.52374 action_loss: 31.26998
# update_step:  53 model loss: 20.12691, kl_loss: 4.46792, obs_loss: 14.48905, reward_loss: 1.16994, value_loss: 1.66368 action_loss: 31.60475
# update_step:  54 model loss: 20.44656, kl_loss: 4.31342, obs_loss: 15.09475, reward_loss: 1.03839, value_loss: 1.60861 action_loss: 30.60464
# update_step:  55 model loss: 18.19506, kl_loss: 4.26342, obs_loss: 12.90139, reward_loss: 1.03024, value_loss: 1.66315 action_loss: 32.72186
# update_step:  56 model loss: 15.86328, kl_loss: 4.19660, obs_loss: 10.38248, reward_loss: 1.28420, value_loss: 1.33454 action_loss: 29.52512
# update_step:  57 model loss: 18.01185, kl_loss: 4.19688, obs_loss: 12.97202, reward_loss: 0.84295, value_loss: 2.94657 action_loss: 30.39615
# update_step:  58 model loss: 21.81186, kl_loss: 4.40618, obs_loss: 16.55825, reward_loss: 0.84743, value_loss: 3.75811 action_loss: 30.39927
# update_step:  59 model loss: 19.15511, kl_loss: 4.25946, obs_loss: 13.69647, reward_loss: 1.19918, value_loss: 3.56304 action_loss: 31.66847
# update_step:  60 model loss: 19.57656, kl_loss: 4.27628, obs_loss: 14.42221, reward_loss: 0.87807, value_loss: 4.09950 action_loss: 30.16913
# update_step:  61 model loss: 19.29252, kl_loss: 4.19494, obs_loss: 14.09993, reward_loss: 0.99765, value_loss: 3.50519 action_loss: 28.90093
# update_step:  62 model loss: 17.03201, kl_loss: 4.13662, obs_loss: 11.52063, reward_loss: 1.37476, value_loss: 2.55566 action_loss: 27.89102
# update_step:  63 model loss: 21.97818, kl_loss: 4.42404, obs_loss: 16.58569, reward_loss: 0.96845, value_loss: 2.61329 action_loss: 29.41506
# update_step:  64 model loss: 19.02354, kl_loss: 4.20768, obs_loss: 13.89944, reward_loss: 0.91642, value_loss: 2.44056 action_loss: 30.04051
# update_step:  65 model loss: 16.39668, kl_loss: 4.13225, obs_loss: 11.26316, reward_loss: 1.00127, value_loss: 1.25155 action_loss: 27.84854
# update_step:  66 model loss: 15.23150, kl_loss: 4.05655, obs_loss: 9.66524, reward_loss: 1.50971, value_loss: 1.22229 action_loss: 28.22223
# update_step:  67 model loss: 20.88155, kl_loss: 4.35153, obs_loss: 15.72305, reward_loss: 0.80697, value_loss: 1.34129 action_loss: 29.33673
# update_step:  68 model loss: 18.80682, kl_loss: 4.34666, obs_loss: 13.21733, reward_loss: 1.24283, value_loss: 1.73442 action_loss: 29.10086
# update_step:  69 model loss: 20.38200, kl_loss: 4.39633, obs_loss: 14.77020, reward_loss: 1.21547, value_loss: 1.91339 action_loss: 29.07248
# update_step:  70 model loss: 17.71163, kl_loss: 4.27688, obs_loss: 12.36244, reward_loss: 1.07230, value_loss: 1.71747 action_loss: 27.58201
# update_step:  71 model loss: 17.26850, kl_loss: 4.23292, obs_loss: 11.79262, reward_loss: 1.24296, value_loss: 1.13623 action_loss: 27.04411
# update_step:  72 model loss: 18.27926, kl_loss: 4.20918, obs_loss: 12.95902, reward_loss: 1.11106, value_loss: 0.93054 action_loss: 25.62484
# update_step:  73 model loss: 15.55994, kl_loss: 4.04796, obs_loss: 10.61299, reward_loss: 0.89898, value_loss: 1.24174 action_loss: 25.54451
# update_step:  74 model loss: 17.59884, kl_loss: 4.10441, obs_loss: 12.48233, reward_loss: 1.01210, value_loss: 2.29749 action_loss: 26.64267
# update_step:  75 model loss: 19.07505, kl_loss: 4.28058, obs_loss: 13.80683, reward_loss: 0.98765, value_loss: 3.20762 action_loss: 27.04795
# update_step:  76 model loss: 17.41870, kl_loss: 4.18429, obs_loss: 12.35771, reward_loss: 0.87670, value_loss: 2.06790 action_loss: 26.18271
# update_step:  77 model loss: 15.50904, kl_loss: 4.14631, obs_loss: 10.29847, reward_loss: 1.06425, value_loss: 2.28782 action_loss: 25.27023
# update_step:  78 model loss: 15.66554, kl_loss: 4.09847, obs_loss: 10.16994, reward_loss: 1.39713, value_loss: 2.67672 action_loss: 24.44418
# update_step:  79 model loss: 20.52477, kl_loss: 4.44364, obs_loss: 14.90011, reward_loss: 1.18102, value_loss: 3.54238 action_loss: 25.74891
# update_step:  80 model loss: 17.40357, kl_loss: 4.27176, obs_loss: 11.90920, reward_loss: 1.22261, value_loss: 2.42013 action_loss: 24.76227
# update_step:  81 model loss: 17.44572, kl_loss: 4.18314, obs_loss: 12.17299, reward_loss: 1.08959, value_loss: 1.21960 action_loss: 25.30462
# update_step:  82 model loss: 18.85496, kl_loss: 4.35574, obs_loss: 13.78267, reward_loss: 0.71654, value_loss: 1.58013 action_loss: 25.33768
# update_step:  83 model loss: 18.05751, kl_loss: 4.28592, obs_loss: 12.63391, reward_loss: 1.13769, value_loss: 2.79879 action_loss: 25.90587
# update_step:  84 model loss: 20.25649, kl_loss: 4.25635, obs_loss: 15.15093, reward_loss: 0.84921, value_loss: 4.65332 action_loss: 29.07082
# update_step:  85 model loss: 18.51332, kl_loss: 4.23225, obs_loss: 13.15265, reward_loss: 1.12843, value_loss: 5.48572 action_loss: 26.59117
# update_step:  86 model loss: 18.29180, kl_loss: 4.20152, obs_loss: 12.91668, reward_loss: 1.17361, value_loss: 8.03280 action_loss: 26.69301
# update_step:  87 model loss: 17.38100, kl_loss: 4.18542, obs_loss: 11.56579, reward_loss: 1.62979, value_loss: 6.04398 action_loss: 28.08757
# update_step:  88 model loss: 15.80962, kl_loss: 4.14756, obs_loss: 10.49294, reward_loss: 1.16912, value_loss: 5.33905 action_loss: 26.64342
# update_step:  89 model loss: 18.87955, kl_loss: 4.28797, obs_loss: 13.59596, reward_loss: 0.99563, value_loss: 3.87869 action_loss: 27.47264
# update_step:  90 model loss: 16.62001, kl_loss: 4.17645, obs_loss: 11.59972, reward_loss: 0.84384, value_loss: 4.28507 action_loss: 27.95351
# update_step:  91 model loss: 19.63627, kl_loss: 4.45554, obs_loss: 13.86179, reward_loss: 1.31895, value_loss: 3.09814 action_loss: 26.73944
# update_step:  92 model loss: 17.27040, kl_loss: 4.22800, obs_loss: 11.68213, reward_loss: 1.36028, value_loss: 1.93087 action_loss: 27.81731
# update_step:  93 model loss: 18.21045, kl_loss: 4.23084, obs_loss: 12.84335, reward_loss: 1.13625, value_loss: 2.44864 action_loss: 25.66855
# update_step:  94 model loss: 19.00200, kl_loss: 4.31271, obs_loss: 13.79828, reward_loss: 0.89101, value_loss: 3.31348 action_loss: 29.62817
# update_step:  95 model loss: 17.03685, kl_loss: 4.20629, obs_loss: 11.52867, reward_loss: 1.30188, value_loss: 1.77133 action_loss: 26.31851
# update_step:  96 model loss: 20.84013, kl_loss: 4.38060, obs_loss: 15.53942, reward_loss: 0.92011, value_loss: 2.07975 action_loss: 29.01516
# update_step:  97 model loss: 15.81497, kl_loss: 4.19852, obs_loss: 10.64183, reward_loss: 0.97462, value_loss: 1.19789 action_loss: 28.87954
# update_step:  98 model loss: 19.13453, kl_loss: 4.34557, obs_loss: 13.53495, reward_loss: 1.25401, value_loss: 1.60542 action_loss: 29.85185
# update_step:  99 model loss: 15.24279, kl_loss: 4.13479, obs_loss: 9.95816, reward_loss: 1.14984, value_loss: 2.74295 action_loss: 30.09497
# update_step: 100 model loss: 17.89321, kl_loss: 4.20831, obs_loss: 12.76600, reward_loss: 0.91890, value_loss: 1.72653 action_loss: 30.37283
# elasped time for update: 32.87s
# episode [  29/ 300] is collected. Total reward is -2406.800000
# elasped time for interaction: 4.10s
# update_step:   1 model loss: 18.75764, kl_loss: 4.31954, obs_loss: 13.47518, reward_loss: 0.96293, value_loss: 1.34724 action_loss: 30.13418
# update_step:   2 model loss: 21.51635, kl_loss: 4.26126, obs_loss: 15.95622, reward_loss: 1.29887, value_loss: 2.10267 action_loss: 31.31186
# update_step:   3 model loss: 26.77137, kl_loss: 4.41076, obs_loss: 21.59831, reward_loss: 0.76229, value_loss: 1.83401 action_loss: 28.97631
# update_step:   4 model loss: 23.08243, kl_loss: 4.28037, obs_loss: 17.70562, reward_loss: 1.09643, value_loss: 1.82804 action_loss: 29.52422
# update_step:   5 model loss: 34.51366, kl_loss: 4.12175, obs_loss: 29.14325, reward_loss: 1.24866, value_loss: 2.00399 action_loss: 31.90453
# update_step:   6 model loss: 26.46420, kl_loss: 4.35064, obs_loss: 21.20379, reward_loss: 0.90976, value_loss: 2.39224 action_loss: 31.10158
# update_step:   7 model loss: 26.55742, kl_loss: 4.19753, obs_loss: 20.90418, reward_loss: 1.45570, value_loss: 2.26430 action_loss: 31.20018
# update_step:   8 model loss: 24.32614, kl_loss: 4.37355, obs_loss: 18.90303, reward_loss: 1.04956, value_loss: 2.36820 action_loss: 29.60233
# update_step:   9 model loss: 22.06828, kl_loss: 4.24221, obs_loss: 16.25448, reward_loss: 1.57159, value_loss: 2.03349 action_loss: 29.84242
# update_step:  10 model loss: 17.98490, kl_loss: 4.20320, obs_loss: 12.53814, reward_loss: 1.24357, value_loss: 1.36587 action_loss: 28.55295
# update_step:  11 model loss: 19.83483, kl_loss: 4.46274, obs_loss: 14.40483, reward_loss: 0.96726, value_loss: 2.41042 action_loss: 29.58788
# update_step:  12 model loss: 18.68046, kl_loss: 4.36543, obs_loss: 13.18530, reward_loss: 1.12973, value_loss: 1.95782 action_loss: 27.35136
# update_step:  13 model loss: 23.68414, kl_loss: 4.53884, obs_loss: 18.30381, reward_loss: 0.84150, value_loss: 3.53130 action_loss: 27.03813
# update_step:  14 model loss: 20.37532, kl_loss: 4.36009, obs_loss: 14.86576, reward_loss: 1.14948, value_loss: 3.03308 action_loss: 25.84290
# update_step:  15 model loss: 17.05692, kl_loss: 4.05340, obs_loss: 11.84983, reward_loss: 1.15369, value_loss: 2.12734 action_loss: 26.83487
# update_step:  16 model loss: 19.24136, kl_loss: 4.09383, obs_loss: 13.93695, reward_loss: 1.21057, value_loss: 2.82599 action_loss: 26.24769
# update_step:  17 model loss: 17.86409, kl_loss: 4.03176, obs_loss: 12.53573, reward_loss: 1.29660, value_loss: 1.91346 action_loss: 26.71139
# update_step:  18 model loss: 20.29959, kl_loss: 4.19370, obs_loss: 15.12373, reward_loss: 0.98216, value_loss: 1.90840 action_loss: 26.80150
# update_step:  19 model loss: 19.17356, kl_loss: 4.24201, obs_loss: 13.95646, reward_loss: 0.97508, value_loss: 1.81272 action_loss: 27.11454
# update_step:  20 model loss: 19.91117, kl_loss: 4.26209, obs_loss: 14.34116, reward_loss: 1.30793, value_loss: 1.71331 action_loss: 28.41776
# update_step:  21 model loss: 15.75432, kl_loss: 4.19476, obs_loss: 10.25707, reward_loss: 1.30249, value_loss: 1.59456 action_loss: 25.90830
# update_step:  22 model loss: 18.77377, kl_loss: 4.34308, obs_loss: 13.62981, reward_loss: 0.80087, value_loss: 3.45484 action_loss: 27.71555
# update_step:  23 model loss: 21.26143, kl_loss: 4.38317, obs_loss: 15.63563, reward_loss: 1.24262, value_loss: 2.47477 action_loss: 27.44715
# update_step:  24 model loss: 18.06357, kl_loss: 4.41546, obs_loss: 12.54448, reward_loss: 1.10363, value_loss: 2.99006 action_loss: 27.76378
# update_step:  25 model loss: 19.01884, kl_loss: 4.20764, obs_loss: 13.54774, reward_loss: 1.26346, value_loss: 4.12988 action_loss: 28.26401
# update_step:  26 model loss: 19.19307, kl_loss: 4.32055, obs_loss: 13.96880, reward_loss: 0.90372, value_loss: 4.78622 action_loss: 26.90908
# update_step:  27 model loss: 18.29030, kl_loss: 4.26791, obs_loss: 12.69770, reward_loss: 1.32469, value_loss: 4.62387 action_loss: 26.00380
# update_step:  28 model loss: 18.62122, kl_loss: 4.32898, obs_loss: 13.08762, reward_loss: 1.20462, value_loss: 4.36504 action_loss: 25.14551
# update_step:  29 model loss: 17.81460, kl_loss: 4.15459, obs_loss: 12.27214, reward_loss: 1.38787, value_loss: 1.49927 action_loss: 24.93748
# update_step:  30 model loss: 20.89745, kl_loss: 4.36005, obs_loss: 15.54864, reward_loss: 0.98876, value_loss: 3.53838 action_loss: 26.76597
# update_step:  31 model loss: 21.07108, kl_loss: 4.35955, obs_loss: 15.74195, reward_loss: 0.96958, value_loss: 4.76311 action_loss: 27.20580
# update_step:  32 model loss: 17.25512, kl_loss: 4.25765, obs_loss: 12.16068, reward_loss: 0.83680, value_loss: 3.45685 action_loss: 26.70204
# update_step:  33 model loss: 16.60149, kl_loss: 4.23085, obs_loss: 11.11174, reward_loss: 1.25890, value_loss: 2.59988 action_loss: 24.59254
# update_step:  34 model loss: 20.20870, kl_loss: 4.43949, obs_loss: 14.68786, reward_loss: 1.08136, value_loss: 2.34836 action_loss: 25.03730
# update_step:  35 model loss: 20.65663, kl_loss: 4.44127, obs_loss: 15.06402, reward_loss: 1.15135, value_loss: 1.56357 action_loss: 26.51194
# update_step:  36 model loss: 18.39013, kl_loss: 4.35157, obs_loss: 13.19878, reward_loss: 0.83978, value_loss: 1.72129 action_loss: 27.21829
# update_step:  37 model loss: 14.16536, kl_loss: 4.06149, obs_loss: 9.03595, reward_loss: 1.06792, value_loss: 1.68924 action_loss: 26.67410
# update_step:  38 model loss: 16.81141, kl_loss: 4.28369, obs_loss: 11.58190, reward_loss: 0.94582, value_loss: 3.36129 action_loss: 26.47159
# update_step:  39 model loss: 19.56649, kl_loss: 4.29713, obs_loss: 14.02884, reward_loss: 1.24052, value_loss: 3.64785 action_loss: 27.06396
# update_step:  40 model loss: 18.82728, kl_loss: 4.47429, obs_loss: 12.98238, reward_loss: 1.37061, value_loss: 3.53520 action_loss: 25.08492
# update_step:  41 model loss: 18.72755, kl_loss: 4.34990, obs_loss: 13.54917, reward_loss: 0.82848, value_loss: 4.46669 action_loss: 24.97607
# update_step:  42 model loss: 16.53053, kl_loss: 4.14223, obs_loss: 11.14865, reward_loss: 1.23965, value_loss: 2.75561 action_loss: 26.26906
# update_step:  43 model loss: 16.64758, kl_loss: 4.27631, obs_loss: 11.23854, reward_loss: 1.13274, value_loss: 2.55696 action_loss: 24.50364
# update_step:  44 model loss: 18.49743, kl_loss: 4.24332, obs_loss: 13.42454, reward_loss: 0.82958, value_loss: 2.70955 action_loss: 28.43442
# update_step:  45 model loss: 17.80501, kl_loss: 4.33521, obs_loss: 12.15754, reward_loss: 1.31226, value_loss: 1.30669 action_loss: 27.28694
# update_step:  46 model loss: 17.92014, kl_loss: 4.25322, obs_loss: 12.59019, reward_loss: 1.07673, value_loss: 3.66950 action_loss: 27.48479
# update_step:  47 model loss: 14.43382, kl_loss: 4.14233, obs_loss: 9.10129, reward_loss: 1.19021, value_loss: 1.29179 action_loss: 27.13408
# update_step:  48 model loss: 15.96358, kl_loss: 4.24484, obs_loss: 10.90692, reward_loss: 0.81182, value_loss: 3.38793 action_loss: 25.69773
# update_step:  49 model loss: 16.58743, kl_loss: 4.16980, obs_loss: 11.09507, reward_loss: 1.32256, value_loss: 3.11380 action_loss: 27.58957
# update_step:  50 model loss: 19.22558, kl_loss: 4.36393, obs_loss: 13.68750, reward_loss: 1.17415, value_loss: 4.99128 action_loss: 27.28022
# update_step:  51 model loss: 19.59920, kl_loss: 4.30512, obs_loss: 14.24201, reward_loss: 1.05207, value_loss: 3.03273 action_loss: 25.99720
# update_step:  52 model loss: 19.40627, kl_loss: 4.27106, obs_loss: 14.08716, reward_loss: 1.04805, value_loss: 3.05378 action_loss: 25.47375
# update_step:  53 model loss: 17.73850, kl_loss: 4.29130, obs_loss: 12.75843, reward_loss: 0.68877, value_loss: 4.62719 action_loss: 27.65653
# update_step:  54 model loss: 12.57599, kl_loss: 3.94779, obs_loss: 7.20256, reward_loss: 1.42564, value_loss: 2.63617 action_loss: 27.60546
# update_step:  55 model loss: 17.91931, kl_loss: 4.20227, obs_loss: 12.74462, reward_loss: 0.97242, value_loss: 3.81285 action_loss: 26.01739
# update_step:  56 model loss: 20.17608, kl_loss: 4.29299, obs_loss: 15.21517, reward_loss: 0.66793, value_loss: 4.89149 action_loss: 27.17305
# update_step:  57 model loss: 18.58189, kl_loss: 4.22947, obs_loss: 13.64296, reward_loss: 0.70946, value_loss: 4.67975 action_loss: 25.17574
# update_step:  58 model loss: 14.10528, kl_loss: 4.10698, obs_loss: 9.18420, reward_loss: 0.81409, value_loss: 3.11451 action_loss: 26.22885
# update_step:  59 model loss: 17.06615, kl_loss: 4.21494, obs_loss: 11.86718, reward_loss: 0.98404, value_loss: 2.94316 action_loss: 24.72714
# update_step:  60 model loss: 15.54338, kl_loss: 4.14647, obs_loss: 10.20903, reward_loss: 1.18787, value_loss: 2.74401 action_loss: 25.17739
# update_step:  61 model loss: 18.15529, kl_loss: 4.31407, obs_loss: 13.10365, reward_loss: 0.73758, value_loss: 4.25346 action_loss: 23.85888
# update_step:  62 model loss: 15.63337, kl_loss: 4.14497, obs_loss: 10.31108, reward_loss: 1.17732, value_loss: 2.02053 action_loss: 25.17175
# update_step:  63 model loss: 19.60901, kl_loss: 4.38463, obs_loss: 14.36634, reward_loss: 0.85804, value_loss: 4.06919 action_loss: 24.12577
# update_step:  64 model loss: 18.07737, kl_loss: 4.34998, obs_loss: 12.61742, reward_loss: 1.10998, value_loss: 2.89050 action_loss: 23.16624
# update_step:  65 model loss: 14.88632, kl_loss: 4.00882, obs_loss: 9.74593, reward_loss: 1.13156, value_loss: 2.04540 action_loss: 24.38585
# update_step:  66 model loss: 17.14562, kl_loss: 4.20958, obs_loss: 12.31453, reward_loss: 0.62152, value_loss: 3.12398 action_loss: 25.00021
# update_step:  67 model loss: 18.48582, kl_loss: 4.30381, obs_loss: 13.22277, reward_loss: 0.95924, value_loss: 1.89334 action_loss: 21.98201
# update_step:  68 model loss: 16.35303, kl_loss: 4.27796, obs_loss: 11.01310, reward_loss: 1.06197, value_loss: 4.00548 action_loss: 23.57089
# update_step:  69 model loss: 14.77855, kl_loss: 4.11533, obs_loss: 9.77766, reward_loss: 0.88556, value_loss: 3.10006 action_loss: 20.71189
# update_step:  70 model loss: 18.64860, kl_loss: 4.40649, obs_loss: 13.27088, reward_loss: 0.97123, value_loss: 4.34783 action_loss: 20.69176
# update_step:  71 model loss: 14.37825, kl_loss: 4.17516, obs_loss: 8.74504, reward_loss: 1.45804, value_loss: 1.69172 action_loss: 19.81526
# update_step:  72 model loss: 18.59431, kl_loss: 4.30145, obs_loss: 13.31067, reward_loss: 0.98219, value_loss: 1.97692 action_loss: 21.03141
# update_step:  73 model loss: 18.40605, kl_loss: 4.39897, obs_loss: 13.23553, reward_loss: 0.77156, value_loss: 4.47461 action_loss: 21.99766
# update_step:  74 model loss: 16.56905, kl_loss: 4.16565, obs_loss: 11.25716, reward_loss: 1.14624, value_loss: 2.69876 action_loss: 20.33132
# update_step:  75 model loss: 15.43216, kl_loss: 4.22168, obs_loss: 10.16821, reward_loss: 1.04227, value_loss: 2.81397 action_loss: 19.60006
# update_step:  76 model loss: 15.13432, kl_loss: 4.08521, obs_loss: 9.59405, reward_loss: 1.45506, value_loss: 2.31514 action_loss: 21.91744
# update_step:  77 model loss: 18.82095, kl_loss: 4.28772, obs_loss: 13.57483, reward_loss: 0.95840, value_loss: 2.48709 action_loss: 22.15563
# update_step:  78 model loss: 14.47008, kl_loss: 4.15546, obs_loss: 9.28407, reward_loss: 1.03055, value_loss: 2.50987 action_loss: 20.67797
# update_step:  79 model loss: 17.65533, kl_loss: 4.25653, obs_loss: 12.30186, reward_loss: 1.09694, value_loss: 2.26297 action_loss: 22.19695
# update_step:  80 model loss: 14.91439, kl_loss: 4.06802, obs_loss: 9.57268, reward_loss: 1.27369, value_loss: 2.61064 action_loss: 24.27518
# update_step:  81 model loss: 15.94855, kl_loss: 4.16017, obs_loss: 10.52791, reward_loss: 1.26048, value_loss: 2.03176 action_loss: 22.06920
# update_step:  82 model loss: 17.69871, kl_loss: 4.31808, obs_loss: 12.43325, reward_loss: 0.94737, value_loss: 3.04901 action_loss: 20.50779
# update_step:  83 model loss: 17.42803, kl_loss: 4.31296, obs_loss: 12.01730, reward_loss: 1.09778, value_loss: 2.08582 action_loss: 19.42735
# update_step:  84 model loss: 14.79879, kl_loss: 4.08059, obs_loss: 9.30275, reward_loss: 1.41546, value_loss: 2.65672 action_loss: 20.20383
# update_step:  85 model loss: 16.16871, kl_loss: 4.22160, obs_loss: 11.12297, reward_loss: 0.82414, value_loss: 3.06258 action_loss: 18.86098
# update_step:  86 model loss: 17.58931, kl_loss: 4.35251, obs_loss: 12.50848, reward_loss: 0.72833, value_loss: 3.80462 action_loss: 16.83412
# update_step:  87 model loss: 13.93407, kl_loss: 4.01732, obs_loss: 8.82957, reward_loss: 1.08718, value_loss: 3.14247 action_loss: 18.40966
# update_step:  88 model loss: 14.71334, kl_loss: 4.03346, obs_loss: 9.36888, reward_loss: 1.31099, value_loss: 2.60441 action_loss: 21.29433
# update_step:  89 model loss: 16.66981, kl_loss: 4.28317, obs_loss: 11.50429, reward_loss: 0.88234, value_loss: 3.38161 action_loss: 19.56172
# update_step:  90 model loss: 17.87878, kl_loss: 4.22724, obs_loss: 12.48802, reward_loss: 1.16353, value_loss: 2.65961 action_loss: 21.75333
# update_step:  91 model loss: 15.54792, kl_loss: 4.11811, obs_loss: 10.41876, reward_loss: 1.01106, value_loss: 2.14925 action_loss: 19.73223
# update_step:  92 model loss: 16.91514, kl_loss: 4.21721, obs_loss: 11.80224, reward_loss: 0.89568, value_loss: 3.13099 action_loss: 24.82505
# update_step:  93 model loss: 16.43542, kl_loss: 4.18986, obs_loss: 11.16153, reward_loss: 1.08403, value_loss: 2.04677 action_loss: 21.02026
# update_step:  94 model loss: 13.83207, kl_loss: 4.03209, obs_loss: 8.24964, reward_loss: 1.55035, value_loss: 2.00095 action_loss: 18.76375
# update_step:  95 model loss: 16.88522, kl_loss: 4.17768, obs_loss: 11.78411, reward_loss: 0.92343, value_loss: 2.65044 action_loss: 19.38893
# update_step:  96 model loss: 16.39810, kl_loss: 4.15698, obs_loss: 11.18519, reward_loss: 1.05593, value_loss: 3.16286 action_loss: 21.56965
# update_step:  97 model loss: 16.97378, kl_loss: 4.20723, obs_loss: 11.82533, reward_loss: 0.94123, value_loss: 2.46592 action_loss: 20.84104
# update_step:  98 model loss: 15.92566, kl_loss: 4.12129, obs_loss: 10.59819, reward_loss: 1.20617, value_loss: 2.90613 action_loss: 20.55185
# update_step:  99 model loss: 16.32819, kl_loss: 4.17072, obs_loss: 10.63858, reward_loss: 1.51888, value_loss: 2.76259 action_loss: 21.69877
# update_step: 100 model loss: 16.42355, kl_loss: 4.22391, obs_loss: 11.03524, reward_loss: 1.16441, value_loss: 2.50550 action_loss: 22.47618
# elasped time for update: 32.70s
# episode [  30/ 300] is collected. Total reward is -404.272000
# elasped time for interaction: 0.72s
# update_step:   1 model loss: 17.09868, kl_loss: 4.39057, obs_loss: 11.74087, reward_loss: 0.96724, value_loss: 2.61341 action_loss: 19.88953
# update_step:   2 model loss: 13.57763, kl_loss: 3.95998, obs_loss: 8.03663, reward_loss: 1.58102, value_loss: 2.42318 action_loss: 20.84651
# update_step:   3 model loss: 14.27191, kl_loss: 4.10208, obs_loss: 9.25387, reward_loss: 0.91597, value_loss: 2.04475 action_loss: 22.93812
# update_step:   4 model loss: 15.68407, kl_loss: 4.11676, obs_loss: 10.54255, reward_loss: 1.02477, value_loss: 1.92190 action_loss: 22.79310
# update_step:   5 model loss: 13.23568, kl_loss: 4.07077, obs_loss: 8.23588, reward_loss: 0.92903, value_loss: 1.67087 action_loss: 20.72620
# update_step:   6 model loss: 15.40843, kl_loss: 4.10643, obs_loss: 10.10695, reward_loss: 1.19505, value_loss: 1.39958 action_loss: 22.40423
# update_step:   7 model loss: 17.68685, kl_loss: 4.30822, obs_loss: 12.61176, reward_loss: 0.76686, value_loss: 1.71603 action_loss: 24.69893
# update_step:   8 model loss: 15.73339, kl_loss: 4.10275, obs_loss: 10.62006, reward_loss: 1.01058, value_loss: 2.01667 action_loss: 22.84128
# update_step:   9 model loss: 11.66132, kl_loss: 3.90138, obs_loss: 6.24307, reward_loss: 1.51687, value_loss: 1.50573 action_loss: 22.42768
# update_step:  10 model loss: 13.99387, kl_loss: 4.05358, obs_loss: 8.49236, reward_loss: 1.44793, value_loss: 1.51452 action_loss: 24.90761
# update_step:  11 model loss: 17.80620, kl_loss: 4.24820, obs_loss: 11.89420, reward_loss: 1.66380, value_loss: 1.89209 action_loss: 23.49000
# update_step:  12 model loss: 16.74045, kl_loss: 4.28577, obs_loss: 11.42102, reward_loss: 1.03367, value_loss: 1.68080 action_loss: 22.74391
# update_step:  13 model loss: 20.85407, kl_loss: 4.42624, obs_loss: 15.28413, reward_loss: 1.14370, value_loss: 2.69230 action_loss: 23.57201
# update_step:  14 model loss: 19.65346, kl_loss: 4.32421, obs_loss: 14.14639, reward_loss: 1.18285, value_loss: 2.57855 action_loss: 24.41493
# update_step:  15 model loss: 17.09011, kl_loss: 4.23347, obs_loss: 11.52609, reward_loss: 1.33056, value_loss: 3.19946 action_loss: 22.78413
# update_step:  16 model loss: 15.14788, kl_loss: 4.12999, obs_loss: 10.18632, reward_loss: 0.83157, value_loss: 4.98435 action_loss: 22.63099
# update_step:  17 model loss: 16.39394, kl_loss: 4.15017, obs_loss: 10.60641, reward_loss: 1.63736, value_loss: 4.11678 action_loss: 19.51591
# update_step:  18 model loss: 15.71026, kl_loss: 4.21578, obs_loss: 10.36637, reward_loss: 1.12811, value_loss: 6.42293 action_loss: 22.30462
# update_step:  19 model loss: 14.11790, kl_loss: 4.06594, obs_loss: 8.85573, reward_loss: 1.19624, value_loss: 3.93830 action_loss: 20.71594
# update_step:  20 model loss: 16.77345, kl_loss: 4.18091, obs_loss: 11.20466, reward_loss: 1.38789, value_loss: 4.05302 action_loss: 23.42146
# update_step:  21 model loss: 17.62379, kl_loss: 4.30623, obs_loss: 12.03646, reward_loss: 1.28110, value_loss: 4.54286 action_loss: 21.79557
# update_step:  22 model loss: 18.52722, kl_loss: 4.56821, obs_loss: 13.21975, reward_loss: 0.73926, value_loss: 3.96815 action_loss: 19.58691
# ...
# update_step:  18 model loss: 8.05859, kl_loss: 3.75930, obs_loss: 2.78875, reward_loss: 1.51054, value_loss: 2.07663 action_loss: 24.50419
# update_step:  19 model loss: 9.67328, kl_loss: 3.86995, obs_loss: 4.67797, reward_loss: 1.12536, value_loss: 2.99428 action_loss: 29.65309
# update_step:  20 model loss: 9.05351, kl_loss: 3.81181, obs_loss: 3.98067, reward_loss: 1.26103, value_loss: 1.72432 action_loss: 25.60879
# update_step:  21 model loss: 10.82032, kl_loss: 3.86126, obs_loss: 5.35888, reward_loss: 1.60018, value_loss: 3.50726 action_loss: 24.71316
# update_step:  22 model loss: 8.45057, kl_loss: 3.80799, obs_loss: 3.48296, reward_loss: 1.15962, value_loss: 2.94449 action_loss: 25.12966
# update_step:  23 model loss: 8.98091, kl_loss: 3.76256, obs_loss: 3.75636, reward_loss: 1.46199, value_loss: 2.72482 action_loss: 26.20538
# update_step:  24 model loss: 8.21543, kl_loss: 3.67552, obs_loss: 3.44732, reward_loss: 1.09258, value_loss: 2.02057 action_loss: 23.10699
# update_step:  25 model loss: 10.60957, kl_loss: 4.00217, obs_loss: 5.56224, reward_loss: 1.04516, value_loss: 3.48677 action_loss: 26.24227
# update_step:  26 model loss: 12.37730, kl_loss: 4.08115, obs_loss: 7.46619, reward_loss: 0.82996, value_loss: 4.21596 action_loss: 24.00178
# update_step:  27 model loss: 9.29858, kl_loss: 3.87065, obs_loss: 4.02699, reward_loss: 1.40094, value_loss: 3.47601 action_loss: 28.72120
# update_step:  28 model loss: 9.27305, kl_loss: 3.83924, obs_loss: 3.74940, reward_loss: 1.68441, value_loss: 5.40357 action_loss: 32.84987
# update_step:  29 model loss: 8.80166, kl_loss: 3.84829, obs_loss: 3.59810, reward_loss: 1.35527, value_loss: 3.27997 action_loss: 33.25570
# update_step:  30 model loss: 9.78733, kl_loss: 3.82362, obs_loss: 4.58187, reward_loss: 1.38184, value_loss: 2.82744 action_loss: 27.95243
# update_step:  31 model loss: 8.47123, kl_loss: 3.67721, obs_loss: 3.36008, reward_loss: 1.43394, value_loss: 2.79158 action_loss: 27.92071
# update_step:  32 model loss: 9.73282, kl_loss: 3.83607, obs_loss: 4.62482, reward_loss: 1.27193, value_loss: 3.56141 action_loss: 22.11254
# update_step:  33 model loss: 9.63630, kl_loss: 3.84318, obs_loss: 4.64530, reward_loss: 1.14782, value_loss: 4.41577 action_loss: 24.92659
# update_step:  34 model loss: 9.79902, kl_loss: 3.91873, obs_loss: 4.82278, reward_loss: 1.05751, value_loss: 2.88918 action_loss: 27.97640
# update_step:  35 model loss: 8.86162, kl_loss: 3.72361, obs_loss: 3.64099, reward_loss: 1.49702, value_loss: 2.34963 action_loss: 21.36020
# update_step:  36 model loss: 9.19456, kl_loss: 3.83510, obs_loss: 3.87356, reward_loss: 1.48590, value_loss: 2.49950 action_loss: 29.51838
# update_step:  37 model loss: 10.53530, kl_loss: 3.72443, obs_loss: 5.06882, reward_loss: 1.74205, value_loss: 2.41255 action_loss: 25.66426
# update_step:  38 model loss: 10.72147, kl_loss: 3.94508, obs_loss: 5.75189, reward_loss: 1.02449, value_loss: 2.94221 action_loss: 24.49770
# update_step:  39 model loss: 8.94247, kl_loss: 3.80491, obs_loss: 3.78867, reward_loss: 1.34889, value_loss: 2.18003 action_loss: 27.62620
# update_step:  40 model loss: 8.11902, kl_loss: 3.72787, obs_loss: 3.29657, reward_loss: 1.09458, value_loss: 2.03693 action_loss: 29.39989
# update_step:  41 model loss: 11.59376, kl_loss: 3.87186, obs_loss: 6.06996, reward_loss: 1.65193, value_loss: 3.21828 action_loss: 31.77827
# update_step:  42 model loss: 10.15984, kl_loss: 3.79728, obs_loss: 4.64973, reward_loss: 1.71283, value_loss: 2.88777 action_loss: 28.67478
# update_step:  43 model loss: 8.91053, kl_loss: 3.75188, obs_loss: 3.70317, reward_loss: 1.45548, value_loss: 2.76482 action_loss: 27.01376
# update_step:  44 model loss: 9.19647, kl_loss: 3.79685, obs_loss: 4.08758, reward_loss: 1.31203, value_loss: 2.04833 action_loss: 29.87071
# update_step:  45 model loss: 7.11164, kl_loss: 3.60587, obs_loss: 2.36427, reward_loss: 1.14150, value_loss: 1.89254 action_loss: 26.90615
# update_step:  46 model loss: 8.42242, kl_loss: 3.80402, obs_loss: 3.26494, reward_loss: 1.35347, value_loss: 2.06927 action_loss: 23.83214
# update_step:  47 model loss: 8.80272, kl_loss: 3.87521, obs_loss: 3.66958, reward_loss: 1.25793, value_loss: 2.13449 action_loss: 26.44302
# update_step:  48 model loss: 9.52782, kl_loss: 3.85478, obs_loss: 4.58143, reward_loss: 1.09160, value_loss: 3.20417 action_loss: 25.91825
# update_step:  49 model loss: 11.45229, kl_loss: 3.88905, obs_loss: 6.34904, reward_loss: 1.21420, value_loss: 2.53786 action_loss: 26.28473
# update_step:  50 model loss: 8.97077, kl_loss: 3.74427, obs_loss: 3.73861, reward_loss: 1.48790, value_loss: 2.35661 action_loss: 25.31748
# update_step:  51 model loss: 9.93980, kl_loss: 3.92876, obs_loss: 5.10854, reward_loss: 0.90251, value_loss: 2.47907 action_loss: 30.07221
# update_step:  52 model loss: 8.48009, kl_loss: 3.82926, obs_loss: 3.24275, reward_loss: 1.40808, value_loss: 1.66444 action_loss: 26.98152
# update_step:  53 model loss: 10.03271, kl_loss: 3.96482, obs_loss: 5.05894, reward_loss: 1.00894, value_loss: 2.92968 action_loss: 29.21868
# update_step:  54 model loss: 8.38962, kl_loss: 3.65309, obs_loss: 3.23191, reward_loss: 1.50462, value_loss: 1.86291 action_loss: 22.74885
# update_step:  55 model loss: 8.17723, kl_loss: 3.75645, obs_loss: 3.10259, reward_loss: 1.31819, value_loss: 2.90243 action_loss: 27.82403
# update_step:  56 model loss: 7.93403, kl_loss: 3.80210, obs_loss: 2.94856, reward_loss: 1.18338, value_loss: 2.82042 action_loss: 31.32325
# update_step:  57 model loss: 8.58337, kl_loss: 3.83242, obs_loss: 3.69492, reward_loss: 1.05603, value_loss: 2.69874 action_loss: 27.52469
# update_step:  58 model loss: 9.12128, kl_loss: 3.76482, obs_loss: 3.93340, reward_loss: 1.42306, value_loss: 2.55023 action_loss: 25.13496
# update_step:  59 model loss: 8.95604, kl_loss: 3.70848, obs_loss: 3.48772, reward_loss: 1.75984, value_loss: 2.63015 action_loss: 28.56230
# update_step:  60 model loss: 10.86272, kl_loss: 3.94432, obs_loss: 6.32450, reward_loss: 0.59389, value_loss: 2.98623 action_loss: 23.46112
# update_step:  61 model loss: 9.94974, kl_loss: 3.80479, obs_loss: 4.71044, reward_loss: 1.43451, value_loss: 1.90901 action_loss: 22.91702
# update_step:  62 model loss: 9.39936, kl_loss: 3.82819, obs_loss: 4.25826, reward_loss: 1.31291, value_loss: 1.93877 action_loss: 26.38254
# update_step:  63 model loss: 10.33407, kl_loss: 3.99317, obs_loss: 5.18292, reward_loss: 1.15799, value_loss: 1.92753 action_loss: 27.93910
# update_step:  64 model loss: 8.83569, kl_loss: 3.76724, obs_loss: 3.95866, reward_loss: 1.10980, value_loss: 2.30912 action_loss: 28.68213
# update_step:  65 model loss: 8.77532, kl_loss: 3.70088, obs_loss: 3.74722, reward_loss: 1.32721, value_loss: 1.27447 action_loss: 24.40998
# update_step:  66 model loss: 10.33819, kl_loss: 3.84318, obs_loss: 5.15613, reward_loss: 1.33887, value_loss: 2.87904 action_loss: 29.58622
# update_step:  67 model loss: 8.28711, kl_loss: 3.74972, obs_loss: 3.08523, reward_loss: 1.45217, value_loss: 1.86381 action_loss: 26.83853
# update_step:  68 model loss: 8.87268, kl_loss: 3.75704, obs_loss: 3.82460, reward_loss: 1.29104, value_loss: 2.62215 action_loss: 26.91621
# update_step:  69 model loss: 8.86850, kl_loss: 3.83815, obs_loss: 4.05313, reward_loss: 0.97722, value_loss: 2.33015 action_loss: 27.77168
# update_step:  70 model loss: 9.37075, kl_loss: 3.83615, obs_loss: 4.28088, reward_loss: 1.25373, value_loss: 1.74356 action_loss: 25.60023
# update_step:  71 model loss: 8.66866, kl_loss: 3.80305, obs_loss: 3.30717, reward_loss: 1.55844, value_loss: 1.91568 action_loss: 25.92561
# update_step:  72 model loss: 11.68138, kl_loss: 3.99478, obs_loss: 6.37545, reward_loss: 1.31115, value_loss: 3.10101 action_loss: 22.40911
# update_step:  73 model loss: 11.50677, kl_loss: 3.91670, obs_loss: 6.14946, reward_loss: 1.44061, value_loss: 2.72638 action_loss: 26.32307
# update_step:  74 model loss: 9.14885, kl_loss: 3.78705, obs_loss: 4.23646, reward_loss: 1.12535, value_loss: 3.36872 action_loss: 28.14942
# update_step:  75 model loss: 9.82145, kl_loss: 3.78426, obs_loss: 4.66436, reward_loss: 1.37282, value_loss: 3.99740 action_loss: 25.23430
# update_step:  76 model loss: 11.12814, kl_loss: 3.90231, obs_loss: 5.75655, reward_loss: 1.46928, value_loss: 5.11777 action_loss: 30.00386
# update_step:  77 model loss: 9.25582, kl_loss: 3.87891, obs_loss: 4.04680, reward_loss: 1.33011, value_loss: 2.94468 action_loss: 23.85353
# update_step:  78 model loss: 9.35423, kl_loss: 3.82468, obs_loss: 4.17760, reward_loss: 1.35195, value_loss: 3.09233 action_loss: 25.02326
# update_step:  79 model loss: 8.20966, kl_loss: 3.71106, obs_loss: 3.29660, reward_loss: 1.20200, value_loss: 2.10154 action_loss: 22.36536
# update_step:  80 model loss: 11.65922, kl_loss: 3.89353, obs_loss: 6.07265, reward_loss: 1.69304, value_loss: 2.33068 action_loss: 20.78717
# update_step:  81 model loss: 8.48185, kl_loss: 3.70042, obs_loss: 3.45959, reward_loss: 1.32183, value_loss: 2.70724 action_loss: 26.40863
# update_step:  82 model loss: 11.60802, kl_loss: 4.01301, obs_loss: 6.49139, reward_loss: 1.10363, value_loss: 5.20390 action_loss: 22.19541
# update_step:  83 model loss: 10.99609, kl_loss: 3.87009, obs_loss: 5.85894, reward_loss: 1.26706, value_loss: 2.85092 action_loss: 25.45129
# update_step:  84 model loss: 8.92211, kl_loss: 3.77697, obs_loss: 3.90277, reward_loss: 1.24238, value_loss: 3.12187 action_loss: 29.62481
# update_step:  85 model loss: 10.07444, kl_loss: 3.80827, obs_loss: 4.77454, reward_loss: 1.49164, value_loss: 2.22048 action_loss: 26.73530
# update_step:  86 model loss: 9.04842, kl_loss: 3.79598, obs_loss: 3.93175, reward_loss: 1.32069, value_loss: 2.90322 action_loss: 30.23038
# update_step:  87 model loss: 11.98674, kl_loss: 4.08396, obs_loss: 6.52359, reward_loss: 1.37919, value_loss: 4.21534 action_loss: 27.88182
# update_step:  88 model loss: 9.45363, kl_loss: 3.88647, obs_loss: 3.74777, reward_loss: 1.81940, value_loss: 3.52050 action_loss: 30.47697
# update_step:  89 model loss: 10.70160, kl_loss: 3.99472, obs_loss: 4.92080, reward_loss: 1.78609, value_loss: 3.24132 action_loss: 35.82589
# update_step:  90 model loss: 8.67862, kl_loss: 3.81298, obs_loss: 3.43504, reward_loss: 1.43059, value_loss: 3.76130 action_loss: 30.53990
# update_step:  91 model loss: 8.21102, kl_loss: 3.81503, obs_loss: 3.13073, reward_loss: 1.26526, value_loss: 3.41011 action_loss: 30.24640
# update_step:  92 model loss: 8.66212, kl_loss: 3.81216, obs_loss: 3.61700, reward_loss: 1.23296, value_loss: 4.19190 action_loss: 30.04394
# update_step:  93 model loss: 8.23173, kl_loss: 3.81186, obs_loss: 3.10531, reward_loss: 1.31456, value_loss: 3.10599 action_loss: 28.24645
# update_step:  94 model loss: 8.20852, kl_loss: 3.76670, obs_loss: 3.36412, reward_loss: 1.07770, value_loss: 2.82020 action_loss: 26.22002
# update_step:  95 model loss: 10.92712, kl_loss: 3.99972, obs_loss: 5.79544, reward_loss: 1.13196, value_loss: 3.70288 action_loss: 30.71642
# update_step:  96 model loss: 11.21440, kl_loss: 4.04164, obs_loss: 5.80909, reward_loss: 1.36367, value_loss: 3.93237 action_loss: 29.46364
# update_step:  97 model loss: 8.71971, kl_loss: 3.81221, obs_loss: 3.63291, reward_loss: 1.27459, value_loss: 2.14187 action_loss: 23.45322
# update_step:  98 model loss: 7.81726, kl_loss: 3.74277, obs_loss: 2.69554, reward_loss: 1.37894, value_loss: 2.15762 action_loss: 29.54056
# update_step:  99 model loss: 6.96216, kl_loss: 3.60799, obs_loss: 2.03714, reward_loss: 1.31703, value_loss: 1.76244 action_loss: 29.51010
# update_step: 100 model loss: 9.71365, kl_loss: 3.87477, obs_loss: 4.91018, reward_loss: 0.92870, value_loss: 3.22459 action_loss: 27.19375
# elasped time for update: 32.74s
# episode [  75/ 300] is collected. Total reward is -179.256000
# elasped time for interaction: 1.57s
# update_step:   1 model loss: 10.65760, kl_loss: 3.94184, obs_loss: 5.74321, reward_loss: 0.97254, value_loss: 3.27606 action_loss: 28.95313
# update_step:   2 model loss: 9.21108, kl_loss: 3.83815, obs_loss: 4.45183, reward_loss: 0.92110, value_loss: 4.03732 action_loss: 30.91760
# update_step:   3 model loss: 8.59957, kl_loss: 3.87641, obs_loss: 3.82507, reward_loss: 0.89809, value_loss: 3.33469 action_loss: 29.27087
# update_step:   4 model loss: 8.97766, kl_loss: 3.79367, obs_loss: 3.89197, reward_loss: 1.29202, value_loss: 2.96562 action_loss: 28.21939
# update_step:   5 model loss: 17.04153, kl_loss: 4.13297, obs_loss: 11.74368, reward_loss: 1.16489, value_loss: 3.51237 action_loss: 28.46652
# update_step:   6 model loss: 7.27127, kl_loss: 3.68663, obs_loss: 2.29488, reward_loss: 1.28976, value_loss: 1.90270 action_loss: 29.77654
# update_step:   7 model loss: 7.01059, kl_loss: 3.61334, obs_loss: 1.95419, reward_loss: 1.44306, value_loss: 2.84448 action_loss: 31.28315
# update_step:   8 model loss: 9.21346, kl_loss: 3.86876, obs_loss: 3.92485, reward_loss: 1.41986, value_loss: 3.00613 action_loss: 23.38229
# update_step:   9 model loss: 10.10780, kl_loss: 3.86569, obs_loss: 5.15211, reward_loss: 1.09000, value_loss: 2.84090 action_loss: 31.70640
# update_step:  10 model loss: 12.56327, kl_loss: 3.85440, obs_loss: 6.94923, reward_loss: 1.75964, value_loss: 1.89138 action_loss: 31.46093
# update_step:  11 model loss: 10.54829, kl_loss: 3.97007, obs_loss: 5.63462, reward_loss: 0.94360, value_loss: 2.40934 action_loss: 20.59810
# update_step:  12 model loss: 11.55416, kl_loss: 3.87626, obs_loss: 6.70252, reward_loss: 0.97538, value_loss: 3.21973 action_loss: 30.99835
# update_step:  13 model loss: 11.75534, kl_loss: 3.84801, obs_loss: 6.63843, reward_loss: 1.26889, value_loss: 2.68252 action_loss: 24.41401
# update_step:  14 model loss: 9.42010, kl_loss: 3.70607, obs_loss: 4.67997, reward_loss: 1.03406, value_loss: 2.95010 action_loss: 24.77902
# update_step:  15 model loss: 9.95890, kl_loss: 3.92025, obs_loss: 4.80848, reward_loss: 1.23017, value_loss: 3.93034 action_loss: 26.75849
# update_step:  16 model loss: 10.72576, kl_loss: 3.91910, obs_loss: 5.52175, reward_loss: 1.28491, value_loss: 3.08421 action_loss: 27.49203
# update_step:  17 model loss: 8.81423, kl_loss: 3.82208, obs_loss: 3.82624, reward_loss: 1.16591, value_loss: 2.51709 action_loss: 25.95854
# update_step:  18 model loss: 12.19559, kl_loss: 3.88728, obs_loss: 7.06357, reward_loss: 1.24475, value_loss: 2.76902 action_loss: 23.12448
# update_step:  19 model loss: 11.77614, kl_loss: 4.03904, obs_loss: 6.60536, reward_loss: 1.13175, value_loss: 3.25359 action_loss: 22.13733
# update_step:  20 model loss: 8.95987, kl_loss: 3.82255, obs_loss: 3.83185, reward_loss: 1.30547, value_loss: 2.14333 action_loss: 24.63934
# update_step:  21 model loss: 9.98387, kl_loss: 3.88076, obs_loss: 4.87616, reward_loss: 1.22695, value_loss: 2.66452 action_loss: 23.69252
# update_step:  22 model loss: 10.69539, kl_loss: 3.78089, obs_loss: 4.93138, reward_loss: 1.98312, value_loss: 2.14648 action_loss: 25.43918
# update_step:  23 model loss: 8.85433, kl_loss: 3.78060, obs_loss: 3.97532, reward_loss: 1.09841, value_loss: 2.41596 action_loss: 27.58380
# update_step:  24 model loss: 8.19895, kl_loss: 3.68199, obs_loss: 2.92842, reward_loss: 1.58854, value_loss: 2.38371 action_loss: 26.92626
# update_step:  25 model loss: 9.62692, kl_loss: 3.85771, obs_loss: 4.81840, reward_loss: 0.95081, value_loss: 2.15819 action_loss: 24.15612
# update_step:  26 model loss: 9.37388, kl_loss: 3.78630, obs_loss: 4.17606, reward_loss: 1.41152, value_loss: 2.33284 action_loss: 29.70905
# update_step:  27 model loss: 11.26824, kl_loss: 3.87310, obs_loss: 6.01613, reward_loss: 1.37900, value_loss: 3.55957 action_loss: 25.64801
# update_step:  28 model loss: 7.78976, kl_loss: 3.66454, obs_loss: 3.01633, reward_loss: 1.10889, value_loss: 2.35522 action_loss: 29.41459
# update_step:  29 model loss: 9.02011, kl_loss: 3.72069, obs_loss: 3.86965, reward_loss: 1.42977, value_loss: 3.02775 action_loss: 31.33896
# update_step:  30 model loss: 10.56197, kl_loss: 3.90527, obs_loss: 5.41419, reward_loss: 1.24251, value_loss: 3.42336 action_loss: 27.96916

# %% [markdown]
# TensorBoardで学習結果を確認してみます.

# %%
# %tensorboard --logdir='./logs'

# %%
env.renderToGif(pid = 0, path = "DreamerEpisode" + str(episode))

# %% [markdown]
# ##  10.結果の確認
# 保存された学習済み重みを用いて, 動作を確認してみましょう.

# %% [markdown]
# 学習にはかなりの時間がかかるので, ここでは事前に学習しておいた重みを読み込むことにします. 時間のある方は, 上記のコードで実際に学習した重みを使って同様に試してみてください.

# %%
# 事前にGoogle Driveにあげておいた学習済み重みをダウンロードします
from google_drive_downloader import GoogleDriveDownloader as gdd

file_id = "" # Google Driveにあげた学習済重みのfile idを取得してここにコピペしてください
gdd.download_file_from_google_drive(file_id=file_id,
                                       dest_path='./episode_0100.zip',
                                       unzip=True)

# %%
encoder.load_state_dict(torch.load('/episode_0100/encoder.pth'))
rssm.transition.load_state_dict(torch.load('/episode_0100/rssm.pth'))
rssm.observation.load_state_dict(torch.load('/episode_0100/obs_model.pth'))
action_model.load_state_dict(torch.load('/episode_0100/action_model.pth'))

# %%
# 学習済み重みを用いず, このcolab上で学習したモデルを使うなら, このセルを実行してください.
# あるいは, 定期的に保存されているモデルを読み込むこともできます
encoder.load_state_dict(torch.load(os.path.join(model_log_dir, 'encoder.pth')))
rssm.transition.load_state_dict(torch.load(os.path.join(model_log_dir, 'rssm.pth')))
rssm.observation.load_state_dict(torch.load(os.path.join(model_log_dir, 'obs_model.pth')))
action_model.load_state_dict(torch.load(os.path.join(model_log_dir, 'action_model.pth')))

# %% [markdown]
# 動作の様子を動画で観てみることにします.

# %%
# 結果を動画で観てみるための関数
import matplotlib.pyplot as plt
from matplotlib import animation
from IPython.display import HTML


def display_video(frames):
    plt.figure(figsize=(8, 8), dpi=50)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        plt.title("Step %d" % (i))
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    display(HTML(anim.to_jshtml(default_mode='once')))
    plt.close()

# %%
policy = Agent(encoder, rssm.transition, action_model)
obs = env.reset()
done = False
total_reward = 0
frames = [obs]
while not done:
    action = policy(obs, training=False)
    obs, reward, done, _ = env.step(action)
    total_reward += reward
    frames.append(obs)

print('Total Reward:', total_reward)

# %%
display_video(frames)

# %% [markdown]
# ある時点の適当な観測から, 世界モデルで**open-loop**に未来予測を行わせ, 観測を再構成して視覚的に観てみましょう.

# %%
policy = Agent(encoder, rssm.transition, action_model)
obs = env.reset()
# 最初に適当な回数行動します. この間にrnn_hiddenに観測の系列に関する情報が蓄積されます
for _ in range(np.random.randint(5, 100)):
    action = policy(obs, training=False)
    obs, _, _, _ = env.step(action)

# 現在の観測をベクトルに変換し, それを元にposteriorを計算します.
preprocessed_obs = preprocess_obs(obs)
preprocessed_obs = torch.as_tensor(preprocessed_obs, device=device)
preprocessed_obs = preprocessed_obs.transpose(1, 2).transpose(0, 1).unsqueeze(0)
with torch.no_grad():
    embedded_obs = encoder(preprocessed_obs)

# posteriorからのサンプルとして得られたstateと, policyから取得したrnn_hiddenが低次元の状態表現です.
# open-loopの予測なので, これ以降この2つの変数は状態遷移を表すpriorでしか更新しません.
# (policyの中では, 行動を決定するために観測をリアルタイムで反映してposteriorで更新しています)
rnn_hidden = policy.rnn_hidden
state = rssm.transition.posterior(rnn_hidden, embedded_obs).sample()
frame = np.zeros((64, 128, 3))
frames = []

prediction_length = 100
for _ in range(prediction_length):
    action = policy(obs)
    obs, _, _, _ = env.step(action)

    action = torch.as_tensor(action, device=device).unsqueeze(0)
    with torch.no_grad():
        state_prior, rnn_hidden = rssm.transition.prior(rssm.transition.reccurent(state, action, rnn_hidden))
        state = state_prior.sample()
        predicted_obs = rssm.observation(state, rnn_hidden)#obs_model(state, rnn_hidden)

    frame[:, :64, :] = preprocess_obs(obs)
    frame[:, 64:, :] = predicted_obs.squeeze().transpose(0, 1).transpose(1, 2).cpu().numpy()
    frames.append((frame + 0.5).clip(0.0, 1.0))

# %% [markdown]
# open-loopの動画予測の結果を, 左側に真のフレーム, 右側に予測されたフレームと並べてみてみましょう.

# %%
display_video(frames)

# %% [markdown]
# 以上で演習は終わりです. お疲れ様でした！

# %% [markdown]
# ## 11.参考文献
# [[1]](https://arxiv.org/pdf/1811.04551.pdf) Danijar Hafner, Timothy Lillicrap, Ian Fischer, Ruben Villegas, David Ha, "Learning Latent Dynamics for Planning from Pixels", arXiv, 2019
#
# [[2]](https://arxiv.org/abs/1912.01603) Danijar Hafner, Timothy Lillicrap, Jimmy Ba, Mohammad Norouzi,
# "Dream to Control: Learning Behaviors by Latent Imagination", ICLR2020
